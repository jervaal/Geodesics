# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from scipy.optimize import minimize

def state(t0, p0, l0, t1, p1, l1):
    """ función para crear el estado U(t0,p0,l0).kron(U(t1,p1,l1)).|00> + |11>)/(sqrt(2)) """
    qc = QuantumCircuit(2)
    qc.h(0)
    qc.cx(0,1)
    # qc.x(0)
    qc.u(t0, p0, l0, 0)
    qc.u(t1, p1, l1, 1)
    return Statevector.from_instruction(qc)

def state_cepa(x0, y0, z0, x1, y1, z1):
    """Función para  crear el estado U(x0,y0,z0).kron(U(x1,y1,z1)).|00>"""
    qc = QuantumCircuit(2)
    qc.u(x0, y0, z0, 0)
    qc.u(x1, y1, z1, 1)
    return Statevector.from_instruction(qc)

def d_fs(x, y):
    """distancia flubini study """
    return np.arccos(np.real(x.inner(y)))

def cost(params):
    """Función de costo: 
    Muestra los parametro para cuando la distacia de flubini study es minima
     ¨"""
    
    
    t0, p0, l0, t1, p1, l1, x0, y0, z0, x1, y1, z1 = params
    entangled_state = state(t0, p0, l0, t1, p1, l1)
    separable_state = state_cepa(x0, y0, z0, x1, y1, z1)
    return d_fs(entangled_state, separable_state)

# Rango de parámetros
bounds = [
    (0, np.pi),      # t0
    (0, 2*np.pi),    # p0
    (0, 2*np.pi),    # l0
    (0, np.pi),      # t1
    (0, 2*np.pi),    # p1
    (0, 2*np.pi),    # l1
    (0, np.pi),      # x0
    (0, 2*np.pi),    # y0
    (0, 2*np.pi),    # z0
    (0, np.pi),      # x1
    (0, 2*np.pi),    # y1
    (0, 2*np.pi),    # z1
]

# Valores iniciales aleatorios
x0 = np.random.uniform([b[0] for b in bounds], [b[1] for b in bounds])

# Minimización
res = minimize(cost, x0, bounds=bounds, method='L-BFGS-B')

print("Distancia mínima encontrada (radianes):", res.fun)
print("Parámetros óptimos:", res.x)

# Si quieres convertir la distancia mínima a grados:
print("Distancia mínima (grados):", np.degrees(res.fun))
# Out:
# Distancia mínima encontrada (radianes): 0.7853981633974484
# Parámetros óptimos: [0.         6.28318531 6.28318531 0.         6.28318531 2.73279365
#  0.         0.         3.75527811 0.         0.         2.6065315 ]
# Distancia mínima (grados): 45.00000000000001

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from scipy.optimize import differential_evolution

"""
La mismas funciones pero con otro método para minimizar. 
"""
# Estado entrelazado con compuertas H y CX + U en cada qubit
def state(t0, p0, l0, t1, p1, l1):
    qc = QuantumCircuit(2)
    qc.h(0)
    qc.cx(0, 1)
    qc.u(t0, p0, l0, 0)
    qc.u(t1, p1, l1, 1)
    return Statevector.from_instruction(qc)

# Estado separable con compuertas U en cada qubit
def state_cepa(x0, y0, z0, x1, y1, z1):
    qc = QuantumCircuit(2)
    qc.u(x0, y0, z0, 0)
    qc.u(x1, y1, z1, 1)
    return Statevector.from_instruction(qc)

# Distancia de Fubini-Study
def d_fs(x, y):
    return np.arccos(np.real(x.inner(y)))

# Función de costo para minimizar
def cost(params):
    t0, p0, l0, t1, p1, l1, x0, y0, z0, x1, y1, z1 = params
    entangled_state = state(t0, p0, l0, t1, p1, l1)
    separable_state = state_cepa(x0, y0, z0, x1, y1, z1)
    return d_fs(entangled_state, separable_state)

# Definición de los límites de los parámetros
bounds = [
    (0, np.pi),      # t0
    (0, 2*np.pi),    # p0
    (0, 2*np.pi),    # l0
    (0, np.pi),      # t1
    (0, 2*np.pi),    # p1
    (0, 2*np.pi),    # l1
    (0, np.pi),      # x0
    (0, 2*np.pi),    # y0
    (0, 2*np.pi),    # z0
    (0, np.pi),      # x1
    (0, 2*np.pi),    # y1
    (0, 2*np.pi),    # z1
]

# Ejecutar DE
result = differential_evolution(cost, bounds, strategy='best1bin', maxiter=300, popsize=20, tol=1e-6, disp=True)

# Mostrar resultados
print("\n📌 Distancia mínima encontrada (radianes):", result.fun)
print("📌 Distancia mínima (grados):", np.degrees(result.fun))
print("📌 Parámetros óptimos:")
for name, value in zip(['t0', 'p0', 'l0', 't1', 'p1', 'l1', 'x0', 'y0', 'z0', 'x1', 'y1', 'z1'], result.x):
    print(f"{name} = {value:.4f}")
# Out:
# differential_evolution step 1: f(x)= 0.7963360930885398
# differential_evolution step 2: f(x)= 0.7881403091688484
# differential_evolution step 3: f(x)= 0.7881403091688484
# differential_evolution step 4: f(x)= 0.7881403091688484
# differential_evolution step 5: f(x)= 0.7864859943168302
# differential_evolution step 6: f(x)= 0.7864859943168302
# differential_evolution step 7: f(x)= 0.7864002531835173
# differential_evolution step 8: f(x)= 0.7864002531835173
# differential_evolution step 9: f(x)= 0.7864002531835173
# differential_evolution step 10: f(x)= 0.7864002531835173
# differential_evolution step 11: f(x)= 0.7864002531835173
# differential_evolution step 12: f(x)= 0.7864002531835173
# differential_evolution step 13: f(x)= 0.7864002531835173
# differential_evolution step 14: f(x)= 0.7864002531835173
# differential_evolution step 15: f(x)= 0.7864002531835173
# differential_evolution step 16: f(x)= 0.7864002531835173
# differential_evolution step 17: f(x)= 0.7864002531835173
# differential_evolution step 18: f(x)= 0.7864002531835173
# differential_evolution step 19: f(x)= 0.7864002531835173
# differential_evolution step 20: f(x)= 0.7864002531835173
# differential_evolution step 21: f(x)= 0.7864002531835173
# differential_evolution step 22: f(x)= 0.7864002531835173
# differential_evolution step 23: f(x)= 0.7864002531835173
# differential_evolution step 24: f(x)= 0.7856716009899728
# differential_evolution step 25: f(x)= 0.7856716009899728
# differential_evolution step 26: f(x)= 0.7856716009899728
# differential_evolution step 27: f(x)= 0.7856716009899728
# differential_evolution step 28: f(x)= 0.7856716009899728
# differential_evolution step 29: f(x)= 0.7856716009899728
# differential_evolution step 30: f(x)= 0.7856716009899728
# differential_evolution step 31: f(x)= 0.7856716009899728
# differential_evolution step 32: f(x)= 0.7856716009899728
# differential_evolution step 33: f(x)= 0.7856716009899728
# differential_evolution step 34: f(x)= 0.7856716009899728
# differential_evolution step 35: f(x)= 0.7856716009899728
# differential_evolution step 36: f(x)= 0.7856716009899728
# differential_evolution step 37: f(x)= 0.7856716009899728
# differential_evolution step 38: f(x)= 0.7856716009899728
# differential_evolution step 39: f(x)= 0.7856716009899728
# differential_evolution step 40: f(x)= 0.7856716009899728
# differential_evolution step 41: f(x)= 0.7856716009899728
# differential_evolution step 42: f(x)= 0.7856716009899728
# differential_evolution step 43: f(x)= 0.7856716009899728
# differential_evolution step 44: f(x)= 0.7856716009899728
# differential_evolution step 45: f(x)= 0.7856716009899728
# differential_evolution step 46: f(x)= 0.7856716009899728
# differential_evolution step 47: f(x)= 0.7856716009899728
# differential_evolution step 48: f(x)= 0.7856716009899728
# differential_evolution step 49: f(x)= 0.7856716009899728
# differential_evolution step 50: f(x)= 0.7856716009899728
# differential_evolution step 51: f(x)= 0.7856716009899728
# differential_evolution step 52: f(x)= 0.7856716009899728
# differential_evolution step 53: f(x)= 0.7856716009899728
# differential_evolution step 54: f(x)= 0.7856716009899728
# differential_evolution step 55: f(x)= 0.7856716009899728
# differential_evolution step 56: f(x)= 0.7856716009899728
# differential_evolution step 57: f(x)= 0.7856716009899728
# differential_evolution step 58: f(x)= 0.7856716009899728
# differential_evolution step 59: f(x)= 0.7856716009899728
# differential_evolution step 60: f(x)= 0.7856716009899728
# differential_evolution step 61: f(x)= 0.7856716009899728
# differential_evolution step 62: f(x)= 0.7856716009899728
# differential_evolution step 63: f(x)= 0.7856716009899728
# differential_evolution step 64: f(x)= 0.7856716009899728
# differential_evolution step 65: f(x)= 0.7856716009899728
# differential_evolution step 66: f(x)= 0.7856716009899728
# differential_evolution step 67: f(x)= 0.7856716009899728
# differential_evolution step 68: f(x)= 0.7856716009899728
# differential_evolution step 69: f(x)= 0.7856716009899728
# differential_evolution step 70: f(x)= 0.7856716009899728
# differential_evolution step 71: f(x)= 0.7856716009899728
# differential_evolution step 72: f(x)= 0.7856716009899728
# differential_evolution step 73: f(x)= 0.7856716009899728
# differential_evolution step 74: f(x)= 0.7856716009899728
# differential_evolution step 75: f(x)= 0.7856716009899728
# differential_evolution step 76: f(x)= 0.7855439332960271
# differential_evolution step 77: f(x)= 0.7854679270174414
# differential_evolution step 78: f(x)= 0.7854679270174414
# differential_evolution step 79: f(x)= 0.7854679270174414
# differential_evolution step 80: f(x)= 0.7854679270174414
# differential_evolution step 81: f(x)= 0.7854679270174414
# differential_evolution step 82: f(x)= 0.7854679270174414
# differential_evolution step 83: f(x)= 0.7854679270174414
# differential_evolution step 84: f(x)= 0.7854679270174414
# differential_evolution step 85: f(x)= 0.7854679270174414
# differential_evolution step 86: f(x)= 0.7854679270174414
# differential_evolution step 87: f(x)= 0.7854679270174414
# differential_evolution step 88: f(x)= 0.7854418633629193
# differential_evolution step 89: f(x)= 0.7854418633629193
# differential_evolution step 90: f(x)= 0.7854418633629193
# differential_evolution step 91: f(x)= 0.7854418633629193
# differential_evolution step 92: f(x)= 0.7854418633629193
# differential_evolution step 93: f(x)= 0.7854418633629193
# differential_evolution step 94: f(x)= 0.7854418633629193
# differential_evolution step 95: f(x)= 0.7854418633629193
# differential_evolution step 96: f(x)= 0.7854418633629193
# differential_evolution step 97: f(x)= 0.7854418633629193
# differential_evolution step 98: f(x)= 0.7854418633629193
# differential_evolution step 99: f(x)= 0.7854418633629193
# differential_evolution step 100: f(x)= 0.7854418633629193
# differential_evolution step 101: f(x)= 0.7854418633629193
# differential_evolution step 102: f(x)= 0.7854418633629193
# differential_evolution step 103: f(x)= 0.7854418633629193
# differential_evolution step 104: f(x)= 0.7854418633629193
# differential_evolution step 105: f(x)= 0.7854418633629193
# differential_evolution step 106: f(x)= 0.7854418633629193
# differential_evolution step 107: f(x)= 0.7854418633629193
# differential_evolution step 108: f(x)= 0.7854418633629193
# differential_evolution step 109: f(x)= 0.7854418633629193
# differential_evolution step 110: f(x)= 0.7854418633629193
# differential_evolution step 111: f(x)= 0.7854418633629193
# differential_evolution step 112: f(x)= 0.7854418633629193
# differential_evolution step 113: f(x)= 0.7854418633629193
# differential_evolution step 114: f(x)= 0.7854418633629193
# differential_evolution step 115: f(x)= 0.7854418633629193
# differential_evolution step 116: f(x)= 0.7854418633629193
# differential_evolution step 117: f(x)= 0.7854418633629193
# differential_evolution step 118: f(x)= 0.7854418633629193
# differential_evolution step 119: f(x)= 0.7854418633629193
# differential_evolution step 120: f(x)= 0.7854418633629193
# differential_evolution step 121: f(x)= 0.7854418633629193
# differential_evolution step 122: f(x)= 0.7854418633629193
# differential_evolution step 123: f(x)= 0.7854418633629193
# differential_evolution step 124: f(x)= 0.7854418633629193
# differential_evolution step 125: f(x)= 0.7854418633629193
# differential_evolution step 126: f(x)= 0.7854418633629193
# differential_evolution step 127: f(x)= 0.7854418633629193
# differential_evolution step 128: f(x)= 0.7854418633629193
# differential_evolution step 129: f(x)= 0.7854284230193722
# differential_evolution step 130: f(x)= 0.7854284230193722
# differential_evolution step 131: f(x)= 0.7854023077014403
# differential_evolution step 132: f(x)= 0.7854010634198826
# differential_evolution step 133: f(x)= 0.7854010634198826
# differential_evolution step 134: f(x)= 0.7854010634198826
# differential_evolution step 135: f(x)= 0.7854010634198826
# differential_evolution step 136: f(x)= 0.7854010634198826
# differential_evolution step 137: f(x)= 0.7854010634198826
# differential_evolution step 138: f(x)= 0.7854010634198826
# differential_evolution step 139: f(x)= 0.7854010634198826
# differential_evolution step 140: f(x)= 0.7854010634198826
# differential_evolution step 141: f(x)= 0.7854010634198826
# differential_evolution step 142: f(x)= 0.7854010634198826
# differential_evolution step 143: f(x)= 0.7854010634198826
# differential_evolution step 144: f(x)= 0.7854000661704105
# differential_evolution step 145: f(x)= 0.7854000661704105
# differential_evolution step 146: f(x)= 0.7854000661704105
# differential_evolution step 147: f(x)= 0.7854000661704105
# differential_evolution step 148: f(x)= 0.7854000661704105
# differential_evolution step 149: f(x)= 0.7854000661704105
# differential_evolution step 150: f(x)= 0.7854000661704105
# differential_evolution step 151: f(x)= 0.7854000661704105
# differential_evolution step 152: f(x)= 0.7854000661704105
# differential_evolution step 153: f(x)= 0.7854000661704105
# differential_evolution step 154: f(x)= 0.7854000661704105
# differential_evolution step 155: f(x)= 0.7854000661704105
# differential_evolution step 156: f(x)= 0.7854000661704105
# differential_evolution step 157: f(x)= 0.7854000661704105
# differential_evolution step 158: f(x)= 0.7854000661704105
# differential_evolution step 159: f(x)= 0.7854000661704105
# differential_evolution step 160: f(x)= 0.7854000661704105
# differential_evolution step 161: f(x)= 0.7854000661704105
# differential_evolution step 162: f(x)= 0.7854000661704105
# differential_evolution step 163: f(x)= 0.7854000661704105
# differential_evolution step 164: f(x)= 0.7854000661704105
# differential_evolution step 165: f(x)= 0.7854000661704105
# differential_evolution step 166: f(x)= 0.7854000661704105
# differential_evolution step 167: f(x)= 0.7854000661704105
# differential_evolution step 168: f(x)= 0.7854000661704105
# differential_evolution step 169: f(x)= 0.7854000661704105
# differential_evolution step 170: f(x)= 0.7854000661704105
# differential_evolution step 171: f(x)= 0.7854000661704105
# differential_evolution step 172: f(x)= 0.7854000661704105
# differential_evolution step 173: f(x)= 0.7854000661704105
# differential_evolution step 174: f(x)= 0.7854000661704105
# differential_evolution step 175: f(x)= 0.7854000661704105
# differential_evolution step 176: f(x)= 0.7854000661704105
# differential_evolution step 177: f(x)= 0.7854000661704105
# differential_evolution step 178: f(x)= 0.7854000661704105
# differential_evolution step 179: f(x)= 0.7854000661704105
# differential_evolution step 180: f(x)= 0.7854000661704105
# differential_evolution step 181: f(x)= 0.7854000661704105
# differential_evolution step 182: f(x)= 0.7854000661704105
# differential_evolution step 183: f(x)= 0.7854000661704105
# differential_evolution step 184: f(x)= 0.7854000661704105
# differential_evolution step 185: f(x)= 0.7854000661704105
# differential_evolution step 186: f(x)= 0.7854000661704105
# differential_evolution step 187: f(x)= 0.7854000661704105
# differential_evolution step 188: f(x)= 0.7854000661704105
# differential_evolution step 189: f(x)= 0.7854000661704105
# differential_evolution step 190: f(x)= 0.7854000661704105
# differential_evolution step 191: f(x)= 0.7854000661704105
# differential_evolution step 192: f(x)= 0.7854000661704105
# differential_evolution step 193: f(x)= 0.7853983996381806
# differential_evolution step 194: f(x)= 0.7853983996381806
# differential_evolution step 195: f(x)= 0.7853983996381806
# differential_evolution step 196: f(x)= 0.7853983996381806
# differential_evolution step 197: f(x)= 0.7853983996381806
# differential_evolution step 198: f(x)= 0.7853983996381806
# differential_evolution step 199: f(x)= 0.7853983996381806
# differential_evolution step 200: f(x)= 0.7853983996381806
# differential_evolution step 201: f(x)= 0.7853983996381806
# differential_evolution step 202: f(x)= 0.7853983996381806
# differential_evolution step 203: f(x)= 0.7853983996381806
# differential_evolution step 204: f(x)= 0.7853983996381806
# differential_evolution step 205: f(x)= 0.7853983996381806
# differential_evolution step 206: f(x)= 0.7853983996381806
# differential_evolution step 207: f(x)= 0.7853983996381806
# differential_evolution step 208: f(x)= 0.7853983996381806
# differential_evolution step 209: f(x)= 0.7853983996381806
# differential_evolution step 210: f(x)= 0.7853983996381806
# differential_evolution step 211: f(x)= 0.7853983996381806
# differential_evolution step 212: f(x)= 0.7853983996381806
# differential_evolution step 213: f(x)= 0.7853983996381806
# differential_evolution step 214: f(x)= 0.7853983996381806
# differential_evolution step 215: f(x)= 0.7853983996381806
# differential_evolution step 216: f(x)= 0.7853983996381806
# differential_evolution step 217: f(x)= 0.7853983996381806
# differential_evolution step 218: f(x)= 0.7853983996381806
# differential_evolution step 219: f(x)= 0.7853983996381806
# differential_evolution step 220: f(x)= 0.7853983996381806
# differential_evolution step 221: f(x)= 0.7853983996381806
# differential_evolution step 222: f(x)= 0.7853983996381806
# differential_evolution step 223: f(x)= 0.7853983996381806
# differential_evolution step 224: f(x)= 0.7853983996381806
# differential_evolution step 225: f(x)= 0.7853983996381806
# differential_evolution step 226: f(x)= 0.7853983996381806
# differential_evolution step 227: f(x)= 0.7853983996381806
# differential_evolution step 228: f(x)= 0.7853983996381806
# differential_evolution step 229: f(x)= 0.7853983996381806
# differential_evolution step 230: f(x)= 0.7853983996381806
# differential_evolution step 231: f(x)= 0.7853983996381806
# differential_evolution step 232: f(x)= 0.7853983996381806
# differential_evolution step 233: f(x)= 0.7853983996381806
# differential_evolution step 234: f(x)= 0.7853983996381806
# differential_evolution step 235: f(x)= 0.7853983996381806
# differential_evolution step 236: f(x)= 0.7853983996381806
# differential_evolution step 237: f(x)= 0.7853983996381806
# differential_evolution step 238: f(x)= 0.7853983996381806
# differential_evolution step 239: f(x)= 0.7853983996381806
# differential_evolution step 240: f(x)= 0.7853983996381806
# differential_evolution step 241: f(x)= 0.7853983996381806
# differential_evolution step 242: f(x)= 0.7853983996381806
# differential_evolution step 243: f(x)= 0.7853983996381806
# differential_evolution step 244: f(x)= 0.7853983996381806
# differential_evolution step 245: f(x)= 0.7853983996381806
# differential_evolution step 246: f(x)= 0.7853983996381806
# differential_evolution step 247: f(x)= 0.7853983996381806
# differential_evolution step 248: f(x)= 0.7853983996381806
# differential_evolution step 249: f(x)= 0.7853983996381806
# differential_evolution step 250: f(x)= 0.7853983996381806
# differential_evolution step 251: f(x)= 0.7853983996381806
# differential_evolution step 252: f(x)= 0.7853983996381806
# differential_evolution step 253: f(x)= 0.7853983996381806
# differential_evolution step 254: f(x)= 0.7853983996381806
# differential_evolution step 255: f(x)= 0.7853983996381806
# differential_evolution step 256: f(x)= 0.7853983996381806
# differential_evolution step 257: f(x)= 0.7853983996381806
# differential_evolution step 258: f(x)= 0.7853983996381806
# differential_evolution step 259: f(x)= 0.7853983996381806
# differential_evolution step 260: f(x)= 0.7853983996381806
# differential_evolution step 261: f(x)= 0.7853983996381806
# differential_evolution step 262: f(x)= 0.7853983996381806
# differential_evolution step 263: f(x)= 0.7853983996381806
# differential_evolution step 264: f(x)= 0.7853983996381806
# differential_evolution step 265: f(x)= 0.7853983996381806
# differential_evolution step 266: f(x)= 0.7853983996381806
# differential_evolution step 267: f(x)= 0.7853983996381806
# differential_evolution step 268: f(x)= 0.7853983996381806
# differential_evolution step 269: f(x)= 0.7853983996381806
# differential_evolution step 270: f(x)= 0.7853983996381806
# differential_evolution step 271: f(x)= 0.7853983996381806
# differential_evolution step 272: f(x)= 0.7853983996381806
# differential_evolution step 273: f(x)= 0.7853983996381806
# differential_evolution step 274: f(x)= 0.7853983996381806
# differential_evolution step 275: f(x)= 0.7853983996381806
# differential_evolution step 276: f(x)= 0.7853983996381806
# differential_evolution step 277: f(x)= 0.7853983996381806
# differential_evolution step 278: f(x)= 0.7853983996381806
# differential_evolution step 279: f(x)= 0.7853983996381806
# differential_evolution step 280: f(x)= 0.7853983996381806
# differential_evolution step 281: f(x)= 0.7853983996381806
# differential_evolution step 282: f(x)= 0.7853983996381806
# differential_evolution step 283: f(x)= 0.7853983996381806
# differential_evolution step 284: f(x)= 0.7853983996381806
# differential_evolution step 285: f(x)= 0.7853983996381806
# differential_evolution step 286: f(x)= 0.7853983996381806
# differential_evolution step 287: f(x)= 0.7853983996381806
# differential_evolution step 288: f(x)= 0.7853983996381806
# differential_evolution step 289: f(x)= 0.7853983996381806
# differential_evolution step 290: f(x)= 0.7853983996381806
# differential_evolution step 291: f(x)= 0.7853983996381806
# differential_evolution step 292: f(x)= 0.7853983996381806
# differential_evolution step 293: f(x)= 0.7853983996381806
# differential_evolution step 294: f(x)= 0.7853983996381806
# differential_evolution step 295: f(x)= 0.7853983996381806
# differential_evolution step 296: f(x)= 0.7853983996381806
# differential_evolution step 297: f(x)= 0.7853983996381806
# differential_evolution step 298: f(x)= 0.7853983996381806
# differential_evolution step 299: f(x)= 0.7853983996381806
# differential_evolution step 300: f(x)= 0.7853983996381806
# Polishing solution with 'L-BFGS-B'
#
# 📌 Distancia mínima encontrada (radianes): 0.7853982106267187
# 📌 Distancia mínima (grados): 45.00000270603786
# 📌 Parámetros óptimos:
# t0 = 0.0839
# p0 = 3.9833
# l0 = 0.5015
# t1 = 0.0259
# p1 = 1.5482
# l1 = 1.0525
# x0 = 0.1334
# y0 = 3.9784
# z0 = 3.1982
# x1 = 0.0560
# y1 = 2.6341
# z1 = 2.4382

# %%
def state(t0, p0, l0, t1, p1, l1):
    """
    Crear el estado sx.ecr.U.U'|00>, este estado es el maximamente entrelazado con puertas nativas. 
    """
    qc = QuantumCircuit(2)
    qc.sx(0)
    qc.ecr(0, 1)
    qc.u(t0, p0, l0, 0)
    qc.u(t1, p1, l1, 1)
    return Statevector.from_instruction(qc)

# Estado separable con compuertas U en cada qubit
def state_cepa(x0, y0, z0, x1, y1, z1):
    qc = QuantumCircuit(2)
    qc.u(x0, y0, z0, 0)
    qc.u(x1, y1, z1, 1)
    return Statevector.from_instruction(qc)

# %%
x0 = np.random.uniform([b[0] for b in bounds], [b[1] for b in bounds])

# Minimización
res = minimize(cost, x0, bounds=bounds, method='L-BFGS-B')

print("Distancia mínima encontrada (radianes):", res.fun)
print("Parámetros óptimos:", res.x)

# Si quieres convertir la distancia mínima a grados:
print("Distancia mínima (grados):", np.degrees(res.fun))
# Out:
# Distancia mínima encontrada (radianes): 0.7853981633977003
# Parámetros óptimos: [3.14159265 1.5493299  2.43958267 0.88745608 3.19542827 0.25558209
#  1.09922389 1.17333732 1.03839994 1.48039233 2.85451448 2.80052585]
# Distancia mínima (grados): 45.00000000001444

# %%
(t0, p0, l0, t1, p1, l1)= res.x[6:12]
(x0, y0, z0, x1, y1, z1)= res.x[0:6]
params_00  = res.x[6:12]
theta = res.x
def gamma(k):
    """Función para encontarar el camino de estados que se encuentran en la geodesica"""
    theta =  res.fun
    vector = np.cos(k)*state_cepa(x0, y0, z0, x1, y1, z1) + np.sin(k)*(state(t0, p0, l0, t1, p1, l1) - np.cos(theta)*state_cepa(x0, y0, z0, x1, y1, z1) )/(np.sin(theta))
    
    return vector.data

# %%
from qiskit.quantum_info import Operator,Statevector
############################################################
# Distancia de Fubini-Study
def d_fs(x, y):
    return np.arccos(np.real(x.inner(y)))

#############################################################
#  Operators

II = Operator.from_label("II")
XI = Operator.from_label("XI")
ZI = Operator.from_label("ZI")
SXI= Operator.from_label("XI").power(0.5)

IX = Operator.from_label("IX")
IZ = Operator.from_label("IZ")
ISX= Operator.from_label("IX").power(0.5)

XX = Operator.from_label("XX")
ZZ = Operator.from_label("ZZ")
ISX_ISX = (Operator.from_label("X").power(0.5)).tensor(Operator.from_label("X").power(0.5)) 

###################################################################
# Vectors 

initial = Statevector.from_label("00")

cir = QuantumCircuit(2)
cir.sx(0)
cir.ecr(0,1)

final = Statevector(cir)


###################################################################
gates_nativas = [II,XI,ZI,SXI,IX,IZ,ISX, XX, ZZ, ISX_ISX]
gates_str =     ["II","XI","ZI","SXI","IX","IZ","ISX", "XX", "ZZ", "ISX_ISX"]

uno = []
for i in gates_nativas:
    U = np.matmul(i.data, initial.data)
    uno.append(U)

"""Distacia en grados para una compuerta actuando en cada qubit |00>"""
s = 0
for i in uno:
    s += 1
    dis = d_fs(Statevector(i),final)
    print(  np.degrees( dis), " ", gates_str[s-1]  )    
#############################################################################
# Out:
# 69.29518894536457   II
# 69.29518894536457   XI
# 69.29518894536457   ZI
# 90.00000000000001   SXI
# 69.29518894536457   IX
# 69.29518894536457   IZ
# 90.00000000000001   ISX
# 69.29518894536457   XX
# 69.29518894536457   ZZ
# 69.29518894536461   ISX_ISX

# %%
# diatancia flubini staudy y su compuertas para le estado |00> y el estado finala con la ecr


dos = []
for i in gates_nativas:
    for j in uno:
        UU = np.matmul(i.data,j)   
        dos.append(UU)
            
            
gate_dos = []
for i in gates_str:
    for j in gates_str:
        gate_dos.append([i,j])      
        
l = 0
for i in dos:
    l += 1
    dis = d_fs(Statevector(i),final)
    print(  np.degrees( dis), "   ",  gate_dos[l-1])
# Out:
# 69.29518894536457     ['II', 'II']
# 69.29518894536457     ['II', 'XI']
# 69.29518894536457     ['II', 'ZI']
# 90.00000000000001     ['II', 'SXI']
# 69.29518894536457     ['II', 'IX']
# 69.29518894536457     ['II', 'IZ']
# 90.00000000000001     ['II', 'ISX']
# 69.29518894536457     ['II', 'XX']
# 69.29518894536457     ['II', 'ZZ']
# 69.29518894536461     ['II', 'ISX_ISX']
# 69.29518894536457     ['XI', 'II']
# 69.29518894536457     ['XI', 'XI']
# 69.29518894536457     ['XI', 'ZI']
# 45.00000000000003     ['XI', 'SXI']
# 69.29518894536457     ['XI', 'IX']
# 69.29518894536457     ['XI', 'IZ']
# 45.00000000000003     ['XI', 'ISX']
# 69.29518894536457     ['XI', 'XX']
# 69.29518894536457     ['XI', 'ZZ']
# 69.29518894536461     ['XI', 'ISX_ISX']
# 69.29518894536457     ['ZI', 'II']
# 110.70481105463544     ['ZI', 'XI']
# 69.29518894536457     ['ZI', 'ZI']
# 90.0     ['ZI', 'SXI']
# 69.29518894536457     ['ZI', 'IX']
# 69.29518894536457     ['ZI', 'IZ']
# 90.00000000000001     ['ZI', 'ISX']
# 110.70481105463544     ['ZI', 'XX']
# 69.29518894536457     ['ZI', 'ZZ']
# 110.70481105463541     ['ZI', 'ISX_ISX']
# 90.00000000000001     ['SXI', 'II']
# 45.000000000000014     ['SXI', 'XI']
# 90.00000000000001     ['SXI', 'ZI']
# 69.29518894536461     ['SXI', 'SXI']
# 45.00000000000003     ['SXI', 'IX']
# 90.00000000000001     ['SXI', 'IZ']
# 69.29518894536461     ['SXI', 'ISX']
# 90.00000000000001     ['SXI', 'XX']
# 90.00000000000001     ['SXI', 'ZZ']
# 45.00000000000008     ['SXI', 'ISX_ISX']
# 69.29518894536457     ['IX', 'II']
# 69.29518894536457     ['IX', 'XI']
# 69.29518894536457     ['IX', 'ZI']
# 45.00000000000003     ['IX', 'SXI']
# 69.29518894536457     ['IX', 'IX']
# 69.29518894536457     ['IX', 'IZ']
# 45.00000000000003     ['IX', 'ISX']
# 69.29518894536457     ['IX', 'XX']
# 69.29518894536457     ['IX', 'ZZ']
# 69.29518894536461     ['IX', 'ISX_ISX']
# 69.29518894536457     ['IZ', 'II']
# 69.29518894536457     ['IZ', 'XI']
# 69.29518894536457     ['IZ', 'ZI']
# 90.00000000000001     ['IZ', 'SXI']
# 110.70481105463544     ['IZ', 'IX']
# 69.29518894536457     ['IZ', 'IZ']
# 90.0     ['IZ', 'ISX']
# 110.70481105463544     ['IZ', 'XX']
# 69.29518894536457     ['IZ', 'ZZ']
# 110.70481105463541     ['IZ', 'ISX_ISX']
# 90.00000000000001     ['ISX', 'II']
# 45.00000000000003     ['ISX', 'XI']
# 90.00000000000001     ['ISX', 'ZI']
# 69.29518894536461     ['ISX', 'SXI']
# 45.000000000000014     ['ISX', 'IX']
# 90.00000000000001     ['ISX', 'IZ']
# 69.29518894536461     ['ISX', 'ISX']
# 90.00000000000001     ['ISX', 'XX']
# 90.00000000000001     ['ISX', 'ZZ']
# 45.00000000000008     ['ISX', 'ISX_ISX']
# 69.29518894536457     ['XX', 'II']
# 69.29518894536457     ['XX', 'XI']
# 69.29518894536457     ['XX', 'ZI']
# 90.00000000000001     ['XX', 'SXI']
# 69.29518894536457     ['XX', 'IX']
# 69.29518894536457     ['XX', 'IZ']
# 90.00000000000001     ['XX', 'ISX']
# 69.29518894536457     ['XX', 'XX']
# 69.29518894536457     ['XX', 'ZZ']
# 69.29518894536461     ['XX', 'ISX_ISX']
# 69.29518894536457     ['ZZ', 'II']
# 110.70481105463544     ['ZZ', 'XI']
# 69.29518894536457     ['ZZ', 'ZI']
# 90.0     ['ZZ', 'SXI']
# 110.70481105463544     ['ZZ', 'IX']
# 69.29518894536457     ['ZZ', 'IZ']
# 90.0     ['ZZ', 'ISX']
# 69.29518894536457     ['ZZ', 'XX']
# 69.29518894536457     ['ZZ', 'ZZ']
# 110.70481105463543     ['ZZ', 'ISX_ISX']
# 69.29518894536461     ['ISX_ISX', 'II']
# 69.2951889453646     ['ISX_ISX', 'XI']
# 69.29518894536461     ['ISX_ISX', 'ZI']
# 45.00000000000008     ['ISX_ISX', 'SXI']
# 69.2951889453646     ['ISX_ISX', 'IX']
# 69.29518894536461     ['ISX_ISX', 'IZ']
# 45.00000000000008     ['ISX_ISX', 'ISX']
# 69.29518894536461     ['ISX_ISX', 'XX']
# 69.29518894536461     ['ISX_ISX', 'ZZ']
# 69.29518894536463     ['ISX_ISX', 'ISX_ISX']

# %%
tres = []
for i in gates_nativas:
    for j in dos:
        UUU = np.matmul(i.data,j)   
        tres.append(UUU)
            
            
gate_tres = []
for i in gates_str:
    for j in gates_str:
        for k in gates_str:
            gate_tres.append([i,j,k])      
        
l = 0
for i in tres:
    l += 1
    dis = d_fs(Statevector(i),final)
    print(  np.degrees( dis), "   ",  gate_tres[l-1])
# Out:
# 69.29518894536457     ['II', 'II', 'II']
# 69.29518894536457     ['II', 'II', 'XI']
# 69.29518894536457     ['II', 'II', 'ZI']
# 90.00000000000001     ['II', 'II', 'SXI']
# 69.29518894536457     ['II', 'II', 'IX']
# 69.29518894536457     ['II', 'II', 'IZ']
# 90.00000000000001     ['II', 'II', 'ISX']
# 69.29518894536457     ['II', 'II', 'XX']
# 69.29518894536457     ['II', 'II', 'ZZ']
# 69.29518894536461     ['II', 'II', 'ISX_ISX']
# 69.29518894536457     ['II', 'XI', 'II']
# 69.29518894536457     ['II', 'XI', 'XI']
# 69.29518894536457     ['II', 'XI', 'ZI']
# 45.00000000000003     ['II', 'XI', 'SXI']
# 69.29518894536457     ['II', 'XI', 'IX']
# 69.29518894536457     ['II', 'XI', 'IZ']
# 45.00000000000003     ['II', 'XI', 'ISX']
# 69.29518894536457     ['II', 'XI', 'XX']
# 69.29518894536457     ['II', 'XI', 'ZZ']
# 69.29518894536461     ['II', 'XI', 'ISX_ISX']
# 69.29518894536457     ['II', 'ZI', 'II']
# 110.70481105463544     ['II', 'ZI', 'XI']
# 69.29518894536457     ['II', 'ZI', 'ZI']
# 90.0     ['II', 'ZI', 'SXI']
# 69.29518894536457     ['II', 'ZI', 'IX']
# 69.29518894536457     ['II', 'ZI', 'IZ']
# 90.00000000000001     ['II', 'ZI', 'ISX']
# 110.70481105463544     ['II', 'ZI', 'XX']
# 69.29518894536457     ['II', 'ZI', 'ZZ']
# 110.70481105463541     ['II', 'ZI', 'ISX_ISX']
# 90.00000000000001     ['II', 'SXI', 'II']
# 45.000000000000014     ['II', 'SXI', 'XI']
# 90.00000000000001     ['II', 'SXI', 'ZI']
# 69.29518894536461     ['II', 'SXI', 'SXI']
# 45.00000000000003     ['II', 'SXI', 'IX']
# 90.00000000000001     ['II', 'SXI', 'IZ']
# 69.29518894536461     ['II', 'SXI', 'ISX']
# 90.00000000000001     ['II', 'SXI', 'XX']
# 90.00000000000001     ['II', 'SXI', 'ZZ']
# 45.00000000000008     ['II', 'SXI', 'ISX_ISX']
# 69.29518894536457     ['II', 'IX', 'II']
# 69.29518894536457     ['II', 'IX', 'XI']
# 69.29518894536457     ['II', 'IX', 'ZI']
# 45.00000000000003     ['II', 'IX', 'SXI']
# 69.29518894536457     ['II', 'IX', 'IX']
# 69.29518894536457     ['II', 'IX', 'IZ']
# 45.00000000000003     ['II', 'IX', 'ISX']
# 69.29518894536457     ['II', 'IX', 'XX']
# 69.29518894536457     ['II', 'IX', 'ZZ']
# 69.29518894536461     ['II', 'IX', 'ISX_ISX']
# 69.29518894536457     ['II', 'IZ', 'II']
# 69.29518894536457     ['II', 'IZ', 'XI']
# 69.29518894536457     ['II', 'IZ', 'ZI']
# 90.00000000000001     ['II', 'IZ', 'SXI']
# 110.70481105463544     ['II', 'IZ', 'IX']
# 69.29518894536457     ['II', 'IZ', 'IZ']
# 90.0     ['II', 'IZ', 'ISX']
# 110.70481105463544     ['II', 'IZ', 'XX']
# 69.29518894536457     ['II', 'IZ', 'ZZ']
# 110.70481105463541     ['II', 'IZ', 'ISX_ISX']
# 90.00000000000001     ['II', 'ISX', 'II']
# 45.00000000000003     ['II', 'ISX', 'XI']
# 90.00000000000001     ['II', 'ISX', 'ZI']
# 69.29518894536461     ['II', 'ISX', 'SXI']
# 45.000000000000014     ['II', 'ISX', 'IX']
# 90.00000000000001     ['II', 'ISX', 'IZ']
# 69.29518894536461     ['II', 'ISX', 'ISX']
# 90.00000000000001     ['II', 'ISX', 'XX']
# 90.00000000000001     ['II', 'ISX', 'ZZ']
# 45.00000000000008     ['II', 'ISX', 'ISX_ISX']
# 69.29518894536457     ['II', 'XX', 'II']
# 69.29518894536457     ['II', 'XX', 'XI']
# 69.29518894536457     ['II', 'XX', 'ZI']
# 90.00000000000001     ['II', 'XX', 'SXI']
# 69.29518894536457     ['II', 'XX', 'IX']
# 69.29518894536457     ['II', 'XX', 'IZ']
# 90.00000000000001     ['II', 'XX', 'ISX']
# 69.29518894536457     ['II', 'XX', 'XX']
# 69.29518894536457     ['II', 'XX', 'ZZ']
# 69.29518894536461     ['II', 'XX', 'ISX_ISX']
# 69.29518894536457     ['II', 'ZZ', 'II']
# 110.70481105463544     ['II', 'ZZ', 'XI']
# 69.29518894536457     ['II', 'ZZ', 'ZI']
# 90.0     ['II', 'ZZ', 'SXI']
# 110.70481105463544     ['II', 'ZZ', 'IX']
# 69.29518894536457     ['II', 'ZZ', 'IZ']
# 90.0     ['II', 'ZZ', 'ISX']
# 69.29518894536457     ['II', 'ZZ', 'XX']
# 69.29518894536457     ['II', 'ZZ', 'ZZ']
# 110.70481105463543     ['II', 'ZZ', 'ISX_ISX']
# 69.29518894536461     ['II', 'ISX_ISX', 'II']
# 69.2951889453646     ['II', 'ISX_ISX', 'XI']
# 69.29518894536461     ['II', 'ISX_ISX', 'ZI']
# 45.00000000000008     ['II', 'ISX_ISX', 'SXI']
# 69.2951889453646     ['II', 'ISX_ISX', 'IX']
# 69.29518894536461     ['II', 'ISX_ISX', 'IZ']
# 45.00000000000008     ['II', 'ISX_ISX', 'ISX']
# 69.29518894536461     ['II', 'ISX_ISX', 'XX']
# 69.29518894536461     ['II', 'ISX_ISX', 'ZZ']
# 69.29518894536463     ['II', 'ISX_ISX', 'ISX_ISX']
# 69.29518894536457     ['XI', 'II', 'II']
# 69.29518894536457     ['XI', 'II', 'XI']
# 69.29518894536457     ['XI', 'II', 'ZI']
# 45.00000000000003     ['XI', 'II', 'SXI']
# 69.29518894536457     ['XI', 'II', 'IX']
# 69.29518894536457     ['XI', 'II', 'IZ']
# 45.00000000000003     ['XI', 'II', 'ISX']
# 69.29518894536457     ['XI', 'II', 'XX']
# 69.29518894536457     ['XI', 'II', 'ZZ']
# 69.29518894536461     ['XI', 'II', 'ISX_ISX']
# 69.29518894536457     ['XI', 'XI', 'II']
# 69.29518894536457     ['XI', 'XI', 'XI']
# 69.29518894536457     ['XI', 'XI', 'ZI']
# 90.00000000000001     ['XI', 'XI', 'SXI']
# 69.29518894536457     ['XI', 'XI', 'IX']
# 69.29518894536457     ['XI', 'XI', 'IZ']
# 90.00000000000001     ['XI', 'XI', 'ISX']
# 69.29518894536457     ['XI', 'XI', 'XX']
# 69.29518894536457     ['XI', 'XI', 'ZZ']
# 69.29518894536461     ['XI', 'XI', 'ISX_ISX']
# 69.29518894536457     ['XI', 'ZI', 'II']
# 110.70481105463544     ['XI', 'ZI', 'XI']
# 69.29518894536457     ['XI', 'ZI', 'ZI']
# 90.0     ['XI', 'ZI', 'SXI']
# 69.29518894536457     ['XI', 'ZI', 'IX']
# 69.29518894536457     ['XI', 'ZI', 'IZ']
# 45.00000000000003     ['XI', 'ZI', 'ISX']
# 110.70481105463544     ['XI', 'ZI', 'XX']
# 69.29518894536457     ['XI', 'ZI', 'ZZ']
# 69.2951889453646     ['XI', 'ZI', 'ISX_ISX']
# 45.00000000000003     ['XI', 'SXI', 'II']
# 90.00000000000001     ['XI', 'SXI', 'XI']
# 45.00000000000003     ['XI', 'SXI', 'ZI']
# 69.29518894536461     ['XI', 'SXI', 'SXI']
# 90.00000000000001     ['XI', 'SXI', 'IX']
# 45.00000000000003     ['XI', 'SXI', 'IZ']
# 69.29518894536461     ['XI', 'SXI', 'ISX']
# 45.000000000000014     ['XI', 'SXI', 'XX']
# 45.00000000000003     ['XI', 'SXI', 'ZZ']
# 90.00000000000004     ['XI', 'SXI', 'ISX_ISX']
# 69.29518894536457     ['XI', 'IX', 'II']
# 69.29518894536457     ['XI', 'IX', 'XI']
# 69.29518894536457     ['XI', 'IX', 'ZI']
# 90.00000000000001     ['XI', 'IX', 'SXI']
# 69.29518894536457     ['XI', 'IX', 'IX']
# 69.29518894536457     ['XI', 'IX', 'IZ']
# 90.00000000000001     ['XI', 'IX', 'ISX']
# 69.29518894536457     ['XI', 'IX', 'XX']
# 69.29518894536457     ['XI', 'IX', 'ZZ']
# 69.29518894536461     ['XI', 'IX', 'ISX_ISX']
# 69.29518894536457     ['XI', 'IZ', 'II']
# 69.29518894536457     ['XI', 'IZ', 'XI']
# 69.29518894536457     ['XI', 'IZ', 'ZI']
# 45.00000000000003     ['XI', 'IZ', 'SXI']
# 110.70481105463544     ['XI', 'IZ', 'IX']
# 69.29518894536457     ['XI', 'IZ', 'IZ']
# 90.0     ['XI', 'IZ', 'ISX']
# 110.70481105463544     ['XI', 'IZ', 'XX']
# 69.29518894536457     ['XI', 'IZ', 'ZZ']
# 69.2951889453646     ['XI', 'IZ', 'ISX_ISX']
# 45.00000000000003     ['XI', 'ISX', 'II']
# 90.00000000000001     ['XI', 'ISX', 'XI']
# 45.00000000000003     ['XI', 'ISX', 'ZI']
# 69.29518894536461     ['XI', 'ISX', 'SXI']
# 90.00000000000001     ['XI', 'ISX', 'IX']
# 45.00000000000003     ['XI', 'ISX', 'IZ']
# 69.29518894536461     ['XI', 'ISX', 'ISX']
# 45.000000000000014     ['XI', 'ISX', 'XX']
# 45.00000000000003     ['XI', 'ISX', 'ZZ']
# 90.00000000000004     ['XI', 'ISX', 'ISX_ISX']
# 69.29518894536457     ['XI', 'XX', 'II']
# 69.29518894536457     ['XI', 'XX', 'XI']
# 69.29518894536457     ['XI', 'XX', 'ZI']
# 45.00000000000003     ['XI', 'XX', 'SXI']
# 69.29518894536457     ['XI', 'XX', 'IX']
# 69.29518894536457     ['XI', 'XX', 'IZ']
# 45.00000000000003     ['XI', 'XX', 'ISX']
# 69.29518894536457     ['XI', 'XX', 'XX']
# 69.29518894536457     ['XI', 'XX', 'ZZ']
# 69.29518894536461     ['XI', 'XX', 'ISX_ISX']
# 69.29518894536457     ['XI', 'ZZ', 'II']
# 110.70481105463544     ['XI', 'ZZ', 'XI']
# 69.29518894536457     ['XI', 'ZZ', 'ZI']
# 90.0     ['XI', 'ZZ', 'SXI']
# 110.70481105463544     ['XI', 'ZZ', 'IX']
# 69.29518894536457     ['XI', 'ZZ', 'IZ']
# 90.0     ['XI', 'ZZ', 'ISX']
# 69.29518894536457     ['XI', 'ZZ', 'XX']
# 69.29518894536457     ['XI', 'ZZ', 'ZZ']
# 110.70481105463543     ['XI', 'ZZ', 'ISX_ISX']
# 69.29518894536461     ['XI', 'ISX_ISX', 'II']
# 69.29518894536461     ['XI', 'ISX_ISX', 'XI']
# 69.29518894536461     ['XI', 'ISX_ISX', 'ZI']
# 90.00000000000004     ['XI', 'ISX_ISX', 'SXI']
# 69.29518894536461     ['XI', 'ISX_ISX', 'IX']
# 69.29518894536461     ['XI', 'ISX_ISX', 'IZ']
# 90.00000000000004     ['XI', 'ISX_ISX', 'ISX']
# 69.29518894536459     ['XI', 'ISX_ISX', 'XX']
# 69.29518894536461     ['XI', 'ISX_ISX', 'ZZ']
# 69.29518894536463     ['XI', 'ISX_ISX', 'ISX_ISX']
# 69.29518894536457     ['ZI', 'II', 'II']
# 110.70481105463544     ['ZI', 'II', 'XI']
# 69.29518894536457     ['ZI', 'II', 'ZI']
# 90.0     ['ZI', 'II', 'SXI']
# 69.29518894536457     ['ZI', 'II', 'IX']
# 69.29518894536457     ['ZI', 'II', 'IZ']
# 90.00000000000001     ['ZI', 'II', 'ISX']
# 110.70481105463544     ['ZI', 'II', 'XX']
# 69.29518894536457     ['ZI', 'II', 'ZZ']
# 110.70481105463541     ['ZI', 'II', 'ISX_ISX']
# 110.70481105463544     ['ZI', 'XI', 'II']
# 69.29518894536457     ['ZI', 'XI', 'XI']
# 110.70481105463544     ['ZI', 'XI', 'ZI']
# 90.0     ['ZI', 'XI', 'SXI']
# 110.70481105463544     ['ZI', 'XI', 'IX']
# 110.70481105463544     ['ZI', 'XI', 'IZ']
# 134.99999999999997     ['ZI', 'XI', 'ISX']
# 69.29518894536457     ['ZI', 'XI', 'XX']
# 110.70481105463544     ['ZI', 'XI', 'ZZ']
# 110.70481105463541     ['ZI', 'XI', 'ISX_ISX']
# 69.29518894536457     ['ZI', 'ZI', 'II']
# 69.29518894536457     ['ZI', 'ZI', 'XI']
# 69.29518894536457     ['ZI', 'ZI', 'ZI']
# 90.00000000000001     ['ZI', 'ZI', 'SXI']
# 69.29518894536457     ['ZI', 'ZI', 'IX']
# 69.29518894536457     ['ZI', 'ZI', 'IZ']
# 90.00000000000001     ['ZI', 'ZI', 'ISX']
# 69.29518894536457     ['ZI', 'ZI', 'XX']
# 69.29518894536457     ['ZI', 'ZI', 'ZZ']
# 69.29518894536461     ['ZI', 'ZI', 'ISX_ISX']
# 90.0     ['ZI', 'SXI', 'II']
# 90.00000000000001     ['ZI', 'SXI', 'XI']
# 90.0     ['ZI', 'SXI', 'ZI']
# 110.70481105463543     ['ZI', 'SXI', 'SXI']
# 90.0     ['ZI', 'SXI', 'IX']
# 90.0     ['ZI', 'SXI', 'IZ']
# 110.70481105463541     ['ZI', 'SXI', 'ISX']
# 90.00000000000001     ['ZI', 'SXI', 'XX']
# 90.0     ['ZI', 'SXI', 'ZZ']
# 134.99999999999991     ['ZI', 'SXI', 'ISX_ISX']
# 69.29518894536457     ['ZI', 'IX', 'II']
# 110.70481105463544     ['ZI', 'IX', 'XI']
# 69.29518894536457     ['ZI', 'IX', 'ZI']
# 90.0     ['ZI', 'IX', 'SXI']
# 69.29518894536457     ['ZI', 'IX', 'IX']
# 69.29518894536457     ['ZI', 'IX', 'IZ']
# 45.00000000000003     ['ZI', 'IX', 'ISX']
# 110.70481105463544     ['ZI', 'IX', 'XX']
# 69.29518894536457     ['ZI', 'IX', 'ZZ']
# 69.2951889453646     ['ZI', 'IX', 'ISX_ISX']
# 69.29518894536457     ['ZI', 'IZ', 'II']
# 110.70481105463544     ['ZI', 'IZ', 'XI']
# 69.29518894536457     ['ZI', 'IZ', 'ZI']
# 90.0     ['ZI', 'IZ', 'SXI']
# 110.70481105463544     ['ZI', 'IZ', 'IX']
# 69.29518894536457     ['ZI', 'IZ', 'IZ']
# 90.0     ['ZI', 'IZ', 'ISX']
# 69.29518894536457     ['ZI', 'IZ', 'XX']
# 69.29518894536457     ['ZI', 'IZ', 'ZZ']
# 110.70481105463543     ['ZI', 'IZ', 'ISX_ISX']
# 90.00000000000001     ['ZI', 'ISX', 'II']
# 134.99999999999997     ['ZI', 'ISX', 'XI']
# 90.00000000000001     ['ZI', 'ISX', 'ZI']
# 110.70481105463541     ['ZI', 'ISX', 'SXI']
# 45.000000000000014     ['ZI', 'ISX', 'IX']
# 90.00000000000001     ['ZI', 'ISX', 'IZ']
# 69.29518894536461     ['ZI', 'ISX', 'ISX']
# 90.0     ['ZI', 'ISX', 'XX']
# 90.00000000000001     ['ZI', 'ISX', 'ZZ']
# 90.0     ['ZI', 'ISX', 'ISX_ISX']
# 110.70481105463544     ['ZI', 'XX', 'II']
# 69.29518894536457     ['ZI', 'XX', 'XI']
# 110.70481105463544     ['ZI', 'XX', 'ZI']
# 90.0     ['ZI', 'XX', 'SXI']
# 110.70481105463544     ['ZI', 'XX', 'IX']
# 110.70481105463544     ['ZI', 'XX', 'IZ']
# 89.99999999999999     ['ZI', 'XX', 'ISX']
# 69.29518894536457     ['ZI', 'XX', 'XX']
# 110.70481105463544     ['ZI', 'XX', 'ZZ']
# 69.2951889453646     ['ZI', 'XX', 'ISX_ISX']
# 69.29518894536457     ['ZI', 'ZZ', 'II']
# 69.29518894536457     ['ZI', 'ZZ', 'XI']
# 69.29518894536457     ['ZI', 'ZZ', 'ZI']
# 90.00000000000001     ['ZI', 'ZZ', 'SXI']
# 110.70481105463544     ['ZI', 'ZZ', 'IX']
# 69.29518894536457     ['ZI', 'ZZ', 'IZ']
# 90.0     ['ZI', 'ZZ', 'ISX']
# 110.70481105463544     ['ZI', 'ZZ', 'XX']
# 69.29518894536457     ['ZI', 'ZZ', 'ZZ']
# 110.70481105463541     ['ZI', 'ZZ', 'ISX_ISX']
# 110.70481105463541     ['ZI', 'ISX_ISX', 'II']
# 110.70481105463543     ['ZI', 'ISX_ISX', 'XI']
# 110.70481105463541     ['ZI', 'ISX_ISX', 'ZI']
# 134.99999999999991     ['ZI', 'ISX_ISX', 'SXI']
# 69.2951889453646     ['ZI', 'ISX_ISX', 'IX']
# 110.70481105463541     ['ZI', 'ISX_ISX', 'IZ']
# 90.0     ['ZI', 'ISX_ISX', 'ISX']
# 69.2951889453646     ['ZI', 'ISX_ISX', 'XX']
# 110.70481105463541     ['ZI', 'ISX_ISX', 'ZZ']
# 110.7048110546354     ['ZI', 'ISX_ISX', 'ISX_ISX']
# 90.00000000000001     ['SXI', 'II', 'II']
# 45.000000000000014     ['SXI', 'II', 'XI']
# 90.00000000000001     ['SXI', 'II', 'ZI']
# 69.29518894536461     ['SXI', 'II', 'SXI']
# 45.00000000000003     ['SXI', 'II', 'IX']
# 90.00000000000001     ['SXI', 'II', 'IZ']
# 69.29518894536461     ['SXI', 'II', 'ISX']
# 90.00000000000001     ['SXI', 'II', 'XX']
# 90.00000000000001     ['SXI', 'II', 'ZZ']
# 45.00000000000008     ['SXI', 'II', 'ISX_ISX']
# 45.000000000000014     ['SXI', 'XI', 'II']
# 90.00000000000001     ['SXI', 'XI', 'XI']
# 45.000000000000014     ['SXI', 'XI', 'ZI']
# 69.29518894536461     ['SXI', 'XI', 'SXI']
# 90.00000000000001     ['SXI', 'XI', 'IX']
# 45.000000000000014     ['SXI', 'XI', 'IZ']
# 69.2951889453646     ['SXI', 'XI', 'ISX']
# 45.00000000000003     ['SXI', 'XI', 'XX']
# 45.000000000000014     ['SXI', 'XI', 'ZZ']
# 90.00000000000004     ['SXI', 'XI', 'ISX_ISX']
# 90.00000000000001     ['SXI', 'ZI', 'II']
# 135.0     ['SXI', 'ZI', 'XI']
# 90.00000000000001     ['SXI', 'ZI', 'ZI']
# 110.70481105463541     ['SXI', 'ZI', 'SXI']
# 45.00000000000003     ['SXI', 'ZI', 'IX']
# 90.00000000000001     ['SXI', 'ZI', 'IZ']
# 69.29518894536461     ['SXI', 'ZI', 'ISX']
# 90.0     ['SXI', 'ZI', 'XX']
# 90.00000000000001     ['SXI', 'ZI', 'ZZ']
# 90.00000000000001     ['SXI', 'ZI', 'ISX_ISX']
# 69.29518894536461     ['SXI', 'SXI', 'II']
# 69.2951889453646     ['SXI', 'SXI', 'XI']
# 69.29518894536461     ['SXI', 'SXI', 'ZI']
# 45.00000000000007     ['SXI', 'SXI', 'SXI']
# 69.29518894536461     ['SXI', 'SXI', 'IX']
# 69.29518894536461     ['SXI', 'SXI', 'IZ']
# 45.00000000000008     ['SXI', 'SXI', 'ISX']
# 69.29518894536461     ['SXI', 'SXI', 'XX']
# 69.29518894536461     ['SXI', 'SXI', 'ZZ']
# 69.29518894536463     ['SXI', 'SXI', 'ISX_ISX']
# 45.00000000000003     ['SXI', 'IX', 'II']
# 90.00000000000001     ['SXI', 'IX', 'XI']
# 45.00000000000003     ['SXI', 'IX', 'ZI']
# 69.29518894536461     ['SXI', 'IX', 'SXI']
# 90.00000000000001     ['SXI', 'IX', 'IX']
# 45.00000000000003     ['SXI', 'IX', 'IZ']
# 69.29518894536461     ['SXI', 'IX', 'ISX']
# 45.000000000000014     ['SXI', 'IX', 'XX']
# 45.00000000000003     ['SXI', 'IX', 'ZZ']
# 90.00000000000004     ['SXI', 'IX', 'ISX_ISX']
# 90.00000000000001     ['SXI', 'IZ', 'II']
# 45.000000000000014     ['SXI', 'IZ', 'XI']
# 90.00000000000001     ['SXI', 'IZ', 'ZI']
# 69.29518894536461     ['SXI', 'IZ', 'SXI']
# 134.99999999999997     ['SXI', 'IZ', 'IX']
# 90.00000000000001     ['SXI', 'IZ', 'IZ']
# 110.70481105463541     ['SXI', 'IZ', 'ISX']
# 90.0     ['SXI', 'IZ', 'XX']
# 90.00000000000001     ['SXI', 'IZ', 'ZZ']
# 90.0     ['SXI', 'IZ', 'ISX_ISX']
# 69.29518894536461     ['SXI', 'ISX', 'II']
# 69.2951889453646     ['SXI', 'ISX', 'XI']
# 69.29518894536461     ['SXI', 'ISX', 'ZI']
# 45.00000000000008     ['SXI', 'ISX', 'SXI']
# 69.2951889453646     ['SXI', 'ISX', 'IX']
# 69.29518894536461     ['SXI', 'ISX', 'IZ']
# 45.00000000000008     ['SXI', 'ISX', 'ISX']
# 69.29518894536461     ['SXI', 'ISX', 'XX']
# 69.29518894536461     ['SXI', 'ISX', 'ZZ']
# 69.29518894536463     ['SXI', 'ISX', 'ISX_ISX']
# 90.00000000000001     ['SXI', 'XX', 'II']
# 45.00000000000003     ['SXI', 'XX', 'XI']
# 90.00000000000001     ['SXI', 'XX', 'ZI']
# 69.29518894536461     ['SXI', 'XX', 'SXI']
# 45.000000000000014     ['SXI', 'XX', 'IX']
# 90.00000000000001     ['SXI', 'XX', 'IZ']
# 69.29518894536461     ['SXI', 'XX', 'ISX']
# 90.00000000000001     ['SXI', 'XX', 'XX']
# 90.00000000000001     ['SXI', 'XX', 'ZZ']
# 45.00000000000008     ['SXI', 'XX', 'ISX_ISX']
# 90.00000000000001     ['SXI', 'ZZ', 'II']
# 135.0     ['SXI', 'ZZ', 'XI']
# 90.00000000000001     ['SXI', 'ZZ', 'ZI']
# 110.70481105463541     ['SXI', 'ZZ', 'SXI']
# 134.99999999999997     ['SXI', 'ZZ', 'IX']
# 90.00000000000001     ['SXI', 'ZZ', 'IZ']
# 110.70481105463541     ['SXI', 'ZZ', 'ISX']
# 90.00000000000001     ['SXI', 'ZZ', 'XX']
# 90.00000000000001     ['SXI', 'ZZ', 'ZZ']
# 134.99999999999991     ['SXI', 'ZZ', 'ISX_ISX']
# 45.00000000000008     ['SXI', 'ISX_ISX', 'II']
# 90.00000000000003     ['SXI', 'ISX_ISX', 'XI']
# 45.00000000000008     ['SXI', 'ISX_ISX', 'ZI']
# 69.29518894536463     ['SXI', 'ISX_ISX', 'SXI']
# 90.00000000000004     ['SXI', 'ISX_ISX', 'IX']
# 45.00000000000008     ['SXI', 'ISX_ISX', 'IZ']
# 69.29518894536463     ['SXI', 'ISX_ISX', 'ISX']
# 45.00000000000007     ['SXI', 'ISX_ISX', 'XX']
# 45.00000000000008     ['SXI', 'ISX_ISX', 'ZZ']
# 90.00000000000006     ['SXI', 'ISX_ISX', 'ISX_ISX']
# 69.29518894536457     ['IX', 'II', 'II']
# 69.29518894536457     ['IX', 'II', 'XI']
# 69.29518894536457     ['IX', 'II', 'ZI']
# 45.00000000000003     ['IX', 'II', 'SXI']
# 69.29518894536457     ['IX', 'II', 'IX']
# 69.29518894536457     ['IX', 'II', 'IZ']
# 45.00000000000003     ['IX', 'II', 'ISX']
# 69.29518894536457     ['IX', 'II', 'XX']
# 69.29518894536457     ['IX', 'II', 'ZZ']
# 69.29518894536461     ['IX', 'II', 'ISX_ISX']
# 69.29518894536457     ['IX', 'XI', 'II']
# 69.29518894536457     ['IX', 'XI', 'XI']
# 69.29518894536457     ['IX', 'XI', 'ZI']
# 90.00000000000001     ['IX', 'XI', 'SXI']
# 69.29518894536457     ['IX', 'XI', 'IX']
# 69.29518894536457     ['IX', 'XI', 'IZ']
# 90.00000000000001     ['IX', 'XI', 'ISX']
# 69.29518894536457     ['IX', 'XI', 'XX']
# 69.29518894536457     ['IX', 'XI', 'ZZ']
# 69.29518894536461     ['IX', 'XI', 'ISX_ISX']
# 69.29518894536457     ['IX', 'ZI', 'II']
# 110.70481105463544     ['IX', 'ZI', 'XI']
# 69.29518894536457     ['IX', 'ZI', 'ZI']
# 90.0     ['IX', 'ZI', 'SXI']
# 69.29518894536457     ['IX', 'ZI', 'IX']
# 69.29518894536457     ['IX', 'ZI', 'IZ']
# 45.00000000000003     ['IX', 'ZI', 'ISX']
# 110.70481105463544     ['IX', 'ZI', 'XX']
# 69.29518894536457     ['IX', 'ZI', 'ZZ']
# 69.2951889453646     ['IX', 'ZI', 'ISX_ISX']
# 45.00000000000003     ['IX', 'SXI', 'II']
# 90.00000000000001     ['IX', 'SXI', 'XI']
# 45.00000000000003     ['IX', 'SXI', 'ZI']
# 69.29518894536461     ['IX', 'SXI', 'SXI']
# 90.00000000000001     ['IX', 'SXI', 'IX']
# 45.00000000000003     ['IX', 'SXI', 'IZ']
# 69.29518894536461     ['IX', 'SXI', 'ISX']
# 45.000000000000014     ['IX', 'SXI', 'XX']
# 45.00000000000003     ['IX', 'SXI', 'ZZ']
# 90.00000000000004     ['IX', 'SXI', 'ISX_ISX']
# 69.29518894536457     ['IX', 'IX', 'II']
# 69.29518894536457     ['IX', 'IX', 'XI']
# 69.29518894536457     ['IX', 'IX', 'ZI']
# 90.00000000000001     ['IX', 'IX', 'SXI']
# 69.29518894536457     ['IX', 'IX', 'IX']
# 69.29518894536457     ['IX', 'IX', 'IZ']
# 90.00000000000001     ['IX', 'IX', 'ISX']
# 69.29518894536457     ['IX', 'IX', 'XX']
# 69.29518894536457     ['IX', 'IX', 'ZZ']
# 69.29518894536461     ['IX', 'IX', 'ISX_ISX']
# 69.29518894536457     ['IX', 'IZ', 'II']
# 69.29518894536457     ['IX', 'IZ', 'XI']
# 69.29518894536457     ['IX', 'IZ', 'ZI']
# 45.00000000000003     ['IX', 'IZ', 'SXI']
# 110.70481105463544     ['IX', 'IZ', 'IX']
# 69.29518894536457     ['IX', 'IZ', 'IZ']
# 90.0     ['IX', 'IZ', 'ISX']
# 110.70481105463544     ['IX', 'IZ', 'XX']
# 69.29518894536457     ['IX', 'IZ', 'ZZ']
# 69.2951889453646     ['IX', 'IZ', 'ISX_ISX']
# 45.00000000000003     ['IX', 'ISX', 'II']
# 90.00000000000001     ['IX', 'ISX', 'XI']
# 45.00000000000003     ['IX', 'ISX', 'ZI']
# 69.29518894536461     ['IX', 'ISX', 'SXI']
# 90.00000000000001     ['IX', 'ISX', 'IX']
# 45.00000000000003     ['IX', 'ISX', 'IZ']
# 69.29518894536461     ['IX', 'ISX', 'ISX']
# 45.000000000000014     ['IX', 'ISX', 'XX']
# 45.00000000000003     ['IX', 'ISX', 'ZZ']
# 90.00000000000004     ['IX', 'ISX', 'ISX_ISX']
# 69.29518894536457     ['IX', 'XX', 'II']
# 69.29518894536457     ['IX', 'XX', 'XI']
# 69.29518894536457     ['IX', 'XX', 'ZI']
# 45.00000000000003     ['IX', 'XX', 'SXI']
# 69.29518894536457     ['IX', 'XX', 'IX']
# 69.29518894536457     ['IX', 'XX', 'IZ']
# 45.00000000000003     ['IX', 'XX', 'ISX']
# 69.29518894536457     ['IX', 'XX', 'XX']
# 69.29518894536457     ['IX', 'XX', 'ZZ']
# 69.29518894536461     ['IX', 'XX', 'ISX_ISX']
# 69.29518894536457     ['IX', 'ZZ', 'II']
# 110.70481105463544     ['IX', 'ZZ', 'XI']
# 69.29518894536457     ['IX', 'ZZ', 'ZI']
# 90.0     ['IX', 'ZZ', 'SXI']
# 110.70481105463544     ['IX', 'ZZ', 'IX']
# 69.29518894536457     ['IX', 'ZZ', 'IZ']
# 90.0     ['IX', 'ZZ', 'ISX']
# 69.29518894536457     ['IX', 'ZZ', 'XX']
# 69.29518894536457     ['IX', 'ZZ', 'ZZ']
# 110.70481105463543     ['IX', 'ZZ', 'ISX_ISX']
# 69.29518894536461     ['IX', 'ISX_ISX', 'II']
# 69.29518894536461     ['IX', 'ISX_ISX', 'XI']
# 69.29518894536461     ['IX', 'ISX_ISX', 'ZI']
# 90.00000000000004     ['IX', 'ISX_ISX', 'SXI']
# 69.29518894536461     ['IX', 'ISX_ISX', 'IX']
# 69.29518894536461     ['IX', 'ISX_ISX', 'IZ']
# 90.00000000000004     ['IX', 'ISX_ISX', 'ISX']
# 69.29518894536459     ['IX', 'ISX_ISX', 'XX']
# 69.29518894536461     ['IX', 'ISX_ISX', 'ZZ']
# 69.29518894536463     ['IX', 'ISX_ISX', 'ISX_ISX']
# 69.29518894536457     ['IZ', 'II', 'II']
# 69.29518894536457     ['IZ', 'II', 'XI']
# 69.29518894536457     ['IZ', 'II', 'ZI']
# 90.00000000000001     ['IZ', 'II', 'SXI']
# 110.70481105463544     ['IZ', 'II', 'IX']
# 69.29518894536457     ['IZ', 'II', 'IZ']
# 90.0     ['IZ', 'II', 'ISX']
# 110.70481105463544     ['IZ', 'II', 'XX']
# 69.29518894536457     ['IZ', 'II', 'ZZ']
# 110.70481105463541     ['IZ', 'II', 'ISX_ISX']
# 69.29518894536457     ['IZ', 'XI', 'II']
# 69.29518894536457     ['IZ', 'XI', 'XI']
# 69.29518894536457     ['IZ', 'XI', 'ZI']
# 45.00000000000003     ['IZ', 'XI', 'SXI']
# 110.70481105463544     ['IZ', 'XI', 'IX']
# 69.29518894536457     ['IZ', 'XI', 'IZ']
# 90.0     ['IZ', 'XI', 'ISX']
# 110.70481105463544     ['IZ', 'XI', 'XX']
# 69.29518894536457     ['IZ', 'XI', 'ZZ']
# 69.2951889453646     ['IZ', 'XI', 'ISX_ISX']
# 69.29518894536457     ['IZ', 'ZI', 'II']
# 110.70481105463544     ['IZ', 'ZI', 'XI']
# 69.29518894536457     ['IZ', 'ZI', 'ZI']
# 90.0     ['IZ', 'ZI', 'SXI']
# 110.70481105463544     ['IZ', 'ZI', 'IX']
# 69.29518894536457     ['IZ', 'ZI', 'IZ']
# 90.0     ['IZ', 'ZI', 'ISX']
# 69.29518894536457     ['IZ', 'ZI', 'XX']
# 69.29518894536457     ['IZ', 'ZI', 'ZZ']
# 110.70481105463543     ['IZ', 'ZI', 'ISX_ISX']
# 90.00000000000001     ['IZ', 'SXI', 'II']
# 45.000000000000014     ['IZ', 'SXI', 'XI']
# 90.00000000000001     ['IZ', 'SXI', 'ZI']
# 69.29518894536461     ['IZ', 'SXI', 'SXI']
# 134.99999999999997     ['IZ', 'SXI', 'IX']
# 90.00000000000001     ['IZ', 'SXI', 'IZ']
# 110.70481105463541     ['IZ', 'SXI', 'ISX']
# 90.0     ['IZ', 'SXI', 'XX']
# 90.00000000000001     ['IZ', 'SXI', 'ZZ']
# 90.0     ['IZ', 'SXI', 'ISX_ISX']
# 110.70481105463544     ['IZ', 'IX', 'II']
# 110.70481105463544     ['IZ', 'IX', 'XI']
# 110.70481105463544     ['IZ', 'IX', 'ZI']
# 134.99999999999997     ['IZ', 'IX', 'SXI']
# 69.29518894536457     ['IZ', 'IX', 'IX']
# 110.70481105463544     ['IZ', 'IX', 'IZ']
# 90.0     ['IZ', 'IX', 'ISX']
# 69.29518894536457     ['IZ', 'IX', 'XX']
# 110.70481105463544     ['IZ', 'IX', 'ZZ']
# 110.70481105463541     ['IZ', 'IX', 'ISX_ISX']
# 69.29518894536457     ['IZ', 'IZ', 'II']
# 69.29518894536457     ['IZ', 'IZ', 'XI']
# 69.29518894536457     ['IZ', 'IZ', 'ZI']
# 90.00000000000001     ['IZ', 'IZ', 'SXI']
# 69.29518894536457     ['IZ', 'IZ', 'IX']
# 69.29518894536457     ['IZ', 'IZ', 'IZ']
# 90.00000000000001     ['IZ', 'IZ', 'ISX']
# 69.29518894536457     ['IZ', 'IZ', 'XX']
# 69.29518894536457     ['IZ', 'IZ', 'ZZ']
# 69.29518894536461     ['IZ', 'IZ', 'ISX_ISX']
# 90.0     ['IZ', 'ISX', 'II']
# 90.0     ['IZ', 'ISX', 'XI']
# 90.0     ['IZ', 'ISX', 'ZI']
# 110.70481105463541     ['IZ', 'ISX', 'SXI']
# 90.00000000000001     ['IZ', 'ISX', 'IX']
# 90.0     ['IZ', 'ISX', 'IZ']
# 110.70481105463543     ['IZ', 'ISX', 'ISX']
# 90.00000000000001     ['IZ', 'ISX', 'XX']
# 90.0     ['IZ', 'ISX', 'ZZ']
# 134.99999999999991     ['IZ', 'ISX', 'ISX_ISX']
# 110.70481105463544     ['IZ', 'XX', 'II']
# 110.70481105463544     ['IZ', 'XX', 'XI']
# 110.70481105463544     ['IZ', 'XX', 'ZI']
# 89.99999999999999     ['IZ', 'XX', 'SXI']
# 69.29518894536457     ['IZ', 'XX', 'IX']
# 110.70481105463544     ['IZ', 'XX', 'IZ']
# 90.0     ['IZ', 'XX', 'ISX']
# 69.29518894536457     ['IZ', 'XX', 'XX']
# 110.70481105463544     ['IZ', 'XX', 'ZZ']
# 69.2951889453646     ['IZ', 'XX', 'ISX_ISX']
# 69.29518894536457     ['IZ', 'ZZ', 'II']
# 110.70481105463544     ['IZ', 'ZZ', 'XI']
# 69.29518894536457     ['IZ', 'ZZ', 'ZI']
# 90.0     ['IZ', 'ZZ', 'SXI']
# 69.29518894536457     ['IZ', 'ZZ', 'IX']
# 69.29518894536457     ['IZ', 'ZZ', 'IZ']
# 90.00000000000001     ['IZ', 'ZZ', 'ISX']
# 110.70481105463544     ['IZ', 'ZZ', 'XX']
# 69.29518894536457     ['IZ', 'ZZ', 'ZZ']
# 110.70481105463541     ['IZ', 'ZZ', 'ISX_ISX']
# 110.70481105463541     ['IZ', 'ISX_ISX', 'II']
# 69.2951889453646     ['IZ', 'ISX_ISX', 'XI']
# 110.70481105463541     ['IZ', 'ISX_ISX', 'ZI']
# 90.0     ['IZ', 'ISX_ISX', 'SXI']
# 110.70481105463543     ['IZ', 'ISX_ISX', 'IX']
# 110.70481105463541     ['IZ', 'ISX_ISX', 'IZ']
# 134.99999999999991     ['IZ', 'ISX_ISX', 'ISX']
# 69.2951889453646     ['IZ', 'ISX_ISX', 'XX']
# 110.70481105463541     ['IZ', 'ISX_ISX', 'ZZ']
# 110.7048110546354     ['IZ', 'ISX_ISX', 'ISX_ISX']
# 90.00000000000001     ['ISX', 'II', 'II']
# 45.00000000000003     ['ISX', 'II', 'XI']
# 90.00000000000001     ['ISX', 'II', 'ZI']
# 69.29518894536461     ['ISX', 'II', 'SXI']
# 45.000000000000014     ['ISX', 'II', 'IX']
# 90.00000000000001     ['ISX', 'II', 'IZ']
# 69.29518894536461     ['ISX', 'II', 'ISX']
# 90.00000000000001     ['ISX', 'II', 'XX']
# 90.00000000000001     ['ISX', 'II', 'ZZ']
# 45.00000000000008     ['ISX', 'II', 'ISX_ISX']
# 45.00000000000003     ['ISX', 'XI', 'II']
# 90.00000000000001     ['ISX', 'XI', 'XI']
# 45.00000000000003     ['ISX', 'XI', 'ZI']
# 69.29518894536461     ['ISX', 'XI', 'SXI']
# 90.00000000000001     ['ISX', 'XI', 'IX']
# 45.00000000000003     ['ISX', 'XI', 'IZ']
# 69.29518894536461     ['ISX', 'XI', 'ISX']
# 45.000000000000014     ['ISX', 'XI', 'XX']
# 45.00000000000003     ['ISX', 'XI', 'ZZ']
# 90.00000000000004     ['ISX', 'XI', 'ISX_ISX']
# 90.00000000000001     ['ISX', 'ZI', 'II']
# 134.99999999999997     ['ISX', 'ZI', 'XI']
# 90.00000000000001     ['ISX', 'ZI', 'ZI']
# 110.70481105463541     ['ISX', 'ZI', 'SXI']
# 45.000000000000014     ['ISX', 'ZI', 'IX']
# 90.00000000000001     ['ISX', 'ZI', 'IZ']
# 69.29518894536461     ['ISX', 'ZI', 'ISX']
# 90.0     ['ISX', 'ZI', 'XX']
# 90.00000000000001     ['ISX', 'ZI', 'ZZ']
# 90.0     ['ISX', 'ZI', 'ISX_ISX']
# 69.29518894536461     ['ISX', 'SXI', 'II']
# 69.2951889453646     ['ISX', 'SXI', 'XI']
# 69.29518894536461     ['ISX', 'SXI', 'ZI']
# 45.00000000000008     ['ISX', 'SXI', 'SXI']
# 69.2951889453646     ['ISX', 'SXI', 'IX']
# 69.29518894536461     ['ISX', 'SXI', 'IZ']
# 45.00000000000008     ['ISX', 'SXI', 'ISX']
# 69.29518894536461     ['ISX', 'SXI', 'XX']
# 69.29518894536461     ['ISX', 'SXI', 'ZZ']
# 69.29518894536463     ['ISX', 'SXI', 'ISX_ISX']
# 45.000000000000014     ['ISX', 'IX', 'II']
# 90.00000000000001     ['ISX', 'IX', 'XI']
# 45.000000000000014     ['ISX', 'IX', 'ZI']
# 69.2951889453646     ['ISX', 'IX', 'SXI']
# 90.00000000000001     ['ISX', 'IX', 'IX']
# 45.000000000000014     ['ISX', 'IX', 'IZ']
# 69.29518894536461     ['ISX', 'IX', 'ISX']
# 45.00000000000003     ['ISX', 'IX', 'XX']
# 45.000000000000014     ['ISX', 'IX', 'ZZ']
# 90.00000000000004     ['ISX', 'IX', 'ISX_ISX']
# 90.00000000000001     ['ISX', 'IZ', 'II']
# 45.00000000000003     ['ISX', 'IZ', 'XI']
# 90.00000000000001     ['ISX', 'IZ', 'ZI']
# 69.29518894536461     ['ISX', 'IZ', 'SXI']
# 135.0     ['ISX', 'IZ', 'IX']
# 90.00000000000001     ['ISX', 'IZ', 'IZ']
# 110.70481105463541     ['ISX', 'IZ', 'ISX']
# 90.0     ['ISX', 'IZ', 'XX']
# 90.00000000000001     ['ISX', 'IZ', 'ZZ']
# 90.0     ['ISX', 'IZ', 'ISX_ISX']
# 69.29518894536461     ['ISX', 'ISX', 'II']
# 69.29518894536461     ['ISX', 'ISX', 'XI']
# 69.29518894536461     ['ISX', 'ISX', 'ZI']
# 45.00000000000008     ['ISX', 'ISX', 'SXI']
# 69.2951889453646     ['ISX', 'ISX', 'IX']
# 69.29518894536461     ['ISX', 'ISX', 'IZ']
# 45.00000000000007     ['ISX', 'ISX', 'ISX']
# 69.29518894536461     ['ISX', 'ISX', 'XX']
# 69.29518894536461     ['ISX', 'ISX', 'ZZ']
# 69.29518894536463     ['ISX', 'ISX', 'ISX_ISX']
# 90.00000000000001     ['ISX', 'XX', 'II']
# 45.000000000000014     ['ISX', 'XX', 'XI']
# 90.00000000000001     ['ISX', 'XX', 'ZI']
# 69.29518894536461     ['ISX', 'XX', 'SXI']
# 45.00000000000003     ['ISX', 'XX', 'IX']
# 90.00000000000001     ['ISX', 'XX', 'IZ']
# 69.29518894536461     ['ISX', 'XX', 'ISX']
# 90.00000000000001     ['ISX', 'XX', 'XX']
# 90.00000000000001     ['ISX', 'XX', 'ZZ']
# 45.00000000000009     ['ISX', 'XX', 'ISX_ISX']
# 90.00000000000001     ['ISX', 'ZZ', 'II']
# 134.99999999999997     ['ISX', 'ZZ', 'XI']
# 90.00000000000001     ['ISX', 'ZZ', 'ZI']
# 110.70481105463541     ['ISX', 'ZZ', 'SXI']
# 135.0     ['ISX', 'ZZ', 'IX']
# 90.00000000000001     ['ISX', 'ZZ', 'IZ']
# 110.70481105463541     ['ISX', 'ZZ', 'ISX']
# 90.00000000000001     ['ISX', 'ZZ', 'XX']
# 90.00000000000001     ['ISX', 'ZZ', 'ZZ']
# 134.99999999999991     ['ISX', 'ZZ', 'ISX_ISX']
# 45.00000000000008     ['ISX', 'ISX_ISX', 'II']
# 90.00000000000004     ['ISX', 'ISX_ISX', 'XI']
# 45.00000000000008     ['ISX', 'ISX_ISX', 'ZI']
# 69.29518894536463     ['ISX', 'ISX_ISX', 'SXI']
# 90.00000000000003     ['ISX', 'ISX_ISX', 'IX']
# 45.00000000000008     ['ISX', 'ISX_ISX', 'IZ']
# 69.29518894536463     ['ISX', 'ISX_ISX', 'ISX']
# 45.00000000000007     ['ISX', 'ISX_ISX', 'XX']
# 45.00000000000008     ['ISX', 'ISX_ISX', 'ZZ']
# 90.00000000000006     ['ISX', 'ISX_ISX', 'ISX_ISX']
# 69.29518894536457     ['XX', 'II', 'II']
# 69.29518894536457     ['XX', 'II', 'XI']
# 69.29518894536457     ['XX', 'II', 'ZI']
# 90.00000000000001     ['XX', 'II', 'SXI']
# 69.29518894536457     ['XX', 'II', 'IX']
# 69.29518894536457     ['XX', 'II', 'IZ']
# 90.00000000000001     ['XX', 'II', 'ISX']
# 69.29518894536457     ['XX', 'II', 'XX']
# 69.29518894536457     ['XX', 'II', 'ZZ']
# 69.29518894536461     ['XX', 'II', 'ISX_ISX']
# 69.29518894536457     ['XX', 'XI', 'II']
# 69.29518894536457     ['XX', 'XI', 'XI']
# 69.29518894536457     ['XX', 'XI', 'ZI']
# 45.00000000000003     ['XX', 'XI', 'SXI']
# 69.29518894536457     ['XX', 'XI', 'IX']
# 69.29518894536457     ['XX', 'XI', 'IZ']
# 45.00000000000003     ['XX', 'XI', 'ISX']
# 69.29518894536457     ['XX', 'XI', 'XX']
# 69.29518894536457     ['XX', 'XI', 'ZZ']
# 69.29518894536461     ['XX', 'XI', 'ISX_ISX']
# 69.29518894536457     ['XX', 'ZI', 'II']
# 110.70481105463544     ['XX', 'ZI', 'XI']
# 69.29518894536457     ['XX', 'ZI', 'ZI']
# 90.0     ['XX', 'ZI', 'SXI']
# 69.29518894536457     ['XX', 'ZI', 'IX']
# 69.29518894536457     ['XX', 'ZI', 'IZ']
# 90.00000000000001     ['XX', 'ZI', 'ISX']
# 110.70481105463544     ['XX', 'ZI', 'XX']
# 69.29518894536457     ['XX', 'ZI', 'ZZ']
# 110.70481105463541     ['XX', 'ZI', 'ISX_ISX']
# 90.00000000000001     ['XX', 'SXI', 'II']
# 45.000000000000014     ['XX', 'SXI', 'XI']
# 90.00000000000001     ['XX', 'SXI', 'ZI']
# 69.29518894536461     ['XX', 'SXI', 'SXI']
# 45.00000000000003     ['XX', 'SXI', 'IX']
# 90.00000000000001     ['XX', 'SXI', 'IZ']
# 69.29518894536461     ['XX', 'SXI', 'ISX']
# 90.00000000000001     ['XX', 'SXI', 'XX']
# 90.00000000000001     ['XX', 'SXI', 'ZZ']
# 45.00000000000008     ['XX', 'SXI', 'ISX_ISX']
# 69.29518894536457     ['XX', 'IX', 'II']
# 69.29518894536457     ['XX', 'IX', 'XI']
# 69.29518894536457     ['XX', 'IX', 'ZI']
# 45.00000000000003     ['XX', 'IX', 'SXI']
# 69.29518894536457     ['XX', 'IX', 'IX']
# 69.29518894536457     ['XX', 'IX', 'IZ']
# 45.00000000000003     ['XX', 'IX', 'ISX']
# 69.29518894536457     ['XX', 'IX', 'XX']
# 69.29518894536457     ['XX', 'IX', 'ZZ']
# 69.29518894536461     ['XX', 'IX', 'ISX_ISX']
# 69.29518894536457     ['XX', 'IZ', 'II']
# 69.29518894536457     ['XX', 'IZ', 'XI']
# 69.29518894536457     ['XX', 'IZ', 'ZI']
# 90.00000000000001     ['XX', 'IZ', 'SXI']
# 110.70481105463544     ['XX', 'IZ', 'IX']
# 69.29518894536457     ['XX', 'IZ', 'IZ']
# 90.0     ['XX', 'IZ', 'ISX']
# 110.70481105463544     ['XX', 'IZ', 'XX']
# 69.29518894536457     ['XX', 'IZ', 'ZZ']
# 110.70481105463541     ['XX', 'IZ', 'ISX_ISX']
# 90.00000000000001     ['XX', 'ISX', 'II']
# 45.00000000000003     ['XX', 'ISX', 'XI']
# 90.00000000000001     ['XX', 'ISX', 'ZI']
# 69.29518894536461     ['XX', 'ISX', 'SXI']
# 45.000000000000014     ['XX', 'ISX', 'IX']
# 90.00000000000001     ['XX', 'ISX', 'IZ']
# 69.29518894536461     ['XX', 'ISX', 'ISX']
# 90.00000000000001     ['XX', 'ISX', 'XX']
# 90.00000000000001     ['XX', 'ISX', 'ZZ']
# 45.00000000000008     ['XX', 'ISX', 'ISX_ISX']
# 69.29518894536457     ['XX', 'XX', 'II']
# 69.29518894536457     ['XX', 'XX', 'XI']
# 69.29518894536457     ['XX', 'XX', 'ZI']
# 90.00000000000001     ['XX', 'XX', 'SXI']
# 69.29518894536457     ['XX', 'XX', 'IX']
# 69.29518894536457     ['XX', 'XX', 'IZ']
# 90.00000000000001     ['XX', 'XX', 'ISX']
# 69.29518894536457     ['XX', 'XX', 'XX']
# 69.29518894536457     ['XX', 'XX', 'ZZ']
# 69.29518894536461     ['XX', 'XX', 'ISX_ISX']
# 69.29518894536457     ['XX', 'ZZ', 'II']
# 110.70481105463544     ['XX', 'ZZ', 'XI']
# 69.29518894536457     ['XX', 'ZZ', 'ZI']
# 90.0     ['XX', 'ZZ', 'SXI']
# 110.70481105463544     ['XX', 'ZZ', 'IX']
# 69.29518894536457     ['XX', 'ZZ', 'IZ']
# 90.0     ['XX', 'ZZ', 'ISX']
# 69.29518894536457     ['XX', 'ZZ', 'XX']
# 69.29518894536457     ['XX', 'ZZ', 'ZZ']
# 110.70481105463543     ['XX', 'ZZ', 'ISX_ISX']
# 69.29518894536461     ['XX', 'ISX_ISX', 'II']
# 69.2951889453646     ['XX', 'ISX_ISX', 'XI']
# 69.29518894536461     ['XX', 'ISX_ISX', 'ZI']
# 45.00000000000008     ['XX', 'ISX_ISX', 'SXI']
# 69.2951889453646     ['XX', 'ISX_ISX', 'IX']
# 69.29518894536461     ['XX', 'ISX_ISX', 'IZ']
# 45.00000000000008     ['XX', 'ISX_ISX', 'ISX']
# 69.29518894536461     ['XX', 'ISX_ISX', 'XX']
# 69.29518894536461     ['XX', 'ISX_ISX', 'ZZ']
# 69.29518894536463     ['XX', 'ISX_ISX', 'ISX_ISX']
# 69.29518894536457     ['ZZ', 'II', 'II']
# 110.70481105463544     ['ZZ', 'II', 'XI']
# 69.29518894536457     ['ZZ', 'II', 'ZI']
# 90.0     ['ZZ', 'II', 'SXI']
# 110.70481105463544     ['ZZ', 'II', 'IX']
# 69.29518894536457     ['ZZ', 'II', 'IZ']
# 90.0     ['ZZ', 'II', 'ISX']
# 69.29518894536457     ['ZZ', 'II', 'XX']
# 69.29518894536457     ['ZZ', 'II', 'ZZ']
# 110.70481105463543     ['ZZ', 'II', 'ISX_ISX']
# 110.70481105463544     ['ZZ', 'XI', 'II']
# 69.29518894536457     ['ZZ', 'XI', 'XI']
# 110.70481105463544     ['ZZ', 'XI', 'ZI']
# 90.0     ['ZZ', 'XI', 'SXI']
# 69.29518894536457     ['ZZ', 'XI', 'IX']
# 110.70481105463544     ['ZZ', 'XI', 'IZ']
# 90.0     ['ZZ', 'XI', 'ISX']
# 110.70481105463544     ['ZZ', 'XI', 'XX']
# 110.70481105463544     ['ZZ', 'XI', 'ZZ']
# 69.29518894536459     ['ZZ', 'XI', 'ISX_ISX']
# 69.29518894536457     ['ZZ', 'ZI', 'II']
# 69.29518894536457     ['ZZ', 'ZI', 'XI']
# 69.29518894536457     ['ZZ', 'ZI', 'ZI']
# 90.00000000000001     ['ZZ', 'ZI', 'SXI']
# 110.70481105463544     ['ZZ', 'ZI', 'IX']
# 69.29518894536457     ['ZZ', 'ZI', 'IZ']
# 90.0     ['ZZ', 'ZI', 'ISX']
# 110.70481105463544     ['ZZ', 'ZI', 'XX']
# 69.29518894536457     ['ZZ', 'ZI', 'ZZ']
# 110.70481105463541     ['ZZ', 'ZI', 'ISX_ISX']
# 90.0     ['ZZ', 'SXI', 'II']
# 90.00000000000001     ['ZZ', 'SXI', 'XI']
# 90.0     ['ZZ', 'SXI', 'ZI']
# 110.70481105463543     ['ZZ', 'SXI', 'SXI']
# 90.0     ['ZZ', 'SXI', 'IX']
# 90.0     ['ZZ', 'SXI', 'IZ']
# 110.70481105463543     ['ZZ', 'SXI', 'ISX']
# 90.0     ['ZZ', 'SXI', 'XX']
# 90.0     ['ZZ', 'SXI', 'ZZ']
# 90.0     ['ZZ', 'SXI', 'ISX_ISX']
# 110.70481105463544     ['ZZ', 'IX', 'II']
# 69.29518894536457     ['ZZ', 'IX', 'XI']
# 110.70481105463544     ['ZZ', 'IX', 'ZI']
# 90.0     ['ZZ', 'IX', 'SXI']
# 69.29518894536457     ['ZZ', 'IX', 'IX']
# 110.70481105463544     ['ZZ', 'IX', 'IZ']
# 90.0     ['ZZ', 'IX', 'ISX']
# 110.70481105463544     ['ZZ', 'IX', 'XX']
# 110.70481105463544     ['ZZ', 'IX', 'ZZ']
# 69.29518894536459     ['ZZ', 'IX', 'ISX_ISX']
# 69.29518894536457     ['ZZ', 'IZ', 'II']
# 110.70481105463544     ['ZZ', 'IZ', 'XI']
# 69.29518894536457     ['ZZ', 'IZ', 'ZI']
# 90.0     ['ZZ', 'IZ', 'SXI']
# 69.29518894536457     ['ZZ', 'IZ', 'IX']
# 69.29518894536457     ['ZZ', 'IZ', 'IZ']
# 90.00000000000001     ['ZZ', 'IZ', 'ISX']
# 110.70481105463544     ['ZZ', 'IZ', 'XX']
# 69.29518894536457     ['ZZ', 'IZ', 'ZZ']
# 110.70481105463541     ['ZZ', 'IZ', 'ISX_ISX']
# 90.0     ['ZZ', 'ISX', 'II']
# 90.0     ['ZZ', 'ISX', 'XI']
# 90.0     ['ZZ', 'ISX', 'ZI']
# 110.70481105463543     ['ZZ', 'ISX', 'SXI']
# 90.00000000000001     ['ZZ', 'ISX', 'IX']
# 90.0     ['ZZ', 'ISX', 'IZ']
# 110.70481105463543     ['ZZ', 'ISX', 'ISX']
# 90.0     ['ZZ', 'ISX', 'XX']
# 90.0     ['ZZ', 'ISX', 'ZZ']
# 90.0     ['ZZ', 'ISX', 'ISX_ISX']
# 69.29518894536457     ['ZZ', 'XX', 'II']
# 110.70481105463544     ['ZZ', 'XX', 'XI']
# 69.29518894536457     ['ZZ', 'XX', 'ZI']
# 90.0     ['ZZ', 'XX', 'SXI']
# 110.70481105463544     ['ZZ', 'XX', 'IX']
# 69.29518894536457     ['ZZ', 'XX', 'IZ']
# 90.0     ['ZZ', 'XX', 'ISX']
# 69.29518894536457     ['ZZ', 'XX', 'XX']
# 69.29518894536457     ['ZZ', 'XX', 'ZZ']
# 110.70481105463543     ['ZZ', 'XX', 'ISX_ISX']
# 69.29518894536457     ['ZZ', 'ZZ', 'II']
# 69.29518894536457     ['ZZ', 'ZZ', 'XI']
# 69.29518894536457     ['ZZ', 'ZZ', 'ZI']
# 90.00000000000001     ['ZZ', 'ZZ', 'SXI']
# 69.29518894536457     ['ZZ', 'ZZ', 'IX']
# 69.29518894536457     ['ZZ', 'ZZ', 'IZ']
# 90.00000000000001     ['ZZ', 'ZZ', 'ISX']
# 69.29518894536457     ['ZZ', 'ZZ', 'XX']
# 69.29518894536457     ['ZZ', 'ZZ', 'ZZ']
# 69.29518894536461     ['ZZ', 'ZZ', 'ISX_ISX']
# 110.70481105463543     ['ZZ', 'ISX_ISX', 'II']
# 69.29518894536459     ['ZZ', 'ISX_ISX', 'XI']
# 110.70481105463543     ['ZZ', 'ISX_ISX', 'ZI']
# 90.0     ['ZZ', 'ISX_ISX', 'SXI']
# 69.29518894536459     ['ZZ', 'ISX_ISX', 'IX']
# 110.70481105463543     ['ZZ', 'ISX_ISX', 'IZ']
# 90.0     ['ZZ', 'ISX_ISX', 'ISX']
# 110.70481105463543     ['ZZ', 'ISX_ISX', 'XX']
# 110.70481105463543     ['ZZ', 'ISX_ISX', 'ZZ']
# 69.29518894536457     ['ZZ', 'ISX_ISX', 'ISX_ISX']
# 69.29518894536461     ['ISX_ISX', 'II', 'II']
# 69.2951889453646     ['ISX_ISX', 'II', 'XI']
# 69.29518894536461     ['ISX_ISX', 'II', 'ZI']
# 45.00000000000008     ['ISX_ISX', 'II', 'SXI']
# 69.2951889453646     ['ISX_ISX', 'II', 'IX']
# 69.29518894536461     ['ISX_ISX', 'II', 'IZ']
# 45.00000000000008     ['ISX_ISX', 'II', 'ISX']
# 69.29518894536461     ['ISX_ISX', 'II', 'XX']
# 69.29518894536461     ['ISX_ISX', 'II', 'ZZ']
# 69.29518894536463     ['ISX_ISX', 'II', 'ISX_ISX']
# 69.2951889453646     ['ISX_ISX', 'XI', 'II']
# 69.29518894536461     ['ISX_ISX', 'XI', 'XI']
# 69.2951889453646     ['ISX_ISX', 'XI', 'ZI']
# 90.00000000000004     ['ISX_ISX', 'XI', 'SXI']
# 69.29518894536461     ['ISX_ISX', 'XI', 'IX']
# 69.2951889453646     ['ISX_ISX', 'XI', 'IZ']
# 90.00000000000004     ['ISX_ISX', 'XI', 'ISX']
# 69.2951889453646     ['ISX_ISX', 'XI', 'XX']
# 69.2951889453646     ['ISX_ISX', 'XI', 'ZZ']
# 69.29518894536463     ['ISX_ISX', 'XI', 'ISX_ISX']
# 69.29518894536461     ['ISX_ISX', 'ZI', 'II']
# 110.70481105463541     ['ISX_ISX', 'ZI', 'XI']
# 69.29518894536461     ['ISX_ISX', 'ZI', 'ZI']
# 90.00000000000001     ['ISX_ISX', 'ZI', 'SXI']
# 69.2951889453646     ['ISX_ISX', 'ZI', 'IX']
# 69.29518894536461     ['ISX_ISX', 'ZI', 'IZ']
# 45.00000000000008     ['ISX_ISX', 'ZI', 'ISX']
# 110.7048110546354     ['ISX_ISX', 'ZI', 'XX']
# 69.29518894536461     ['ISX_ISX', 'ZI', 'ZZ']
# 69.29518894536461     ['ISX_ISX', 'ZI', 'ISX_ISX']
# 45.00000000000008     ['ISX_ISX', 'SXI', 'II']
# 90.00000000000003     ['ISX_ISX', 'SXI', 'XI']
# 45.00000000000008     ['ISX_ISX', 'SXI', 'ZI']
# 69.29518894536463     ['ISX_ISX', 'SXI', 'SXI']
# 90.00000000000004     ['ISX_ISX', 'SXI', 'IX']
# 45.00000000000008     ['ISX_ISX', 'SXI', 'IZ']
# 69.29518894536463     ['ISX_ISX', 'SXI', 'ISX']
# 45.00000000000007     ['ISX_ISX', 'SXI', 'XX']
# 45.00000000000008     ['ISX_ISX', 'SXI', 'ZZ']
# 90.00000000000006     ['ISX_ISX', 'SXI', 'ISX_ISX']
# 69.2951889453646     ['ISX_ISX', 'IX', 'II']
# 69.29518894536461     ['ISX_ISX', 'IX', 'XI']
# 69.2951889453646     ['ISX_ISX', 'IX', 'ZI']
# 90.00000000000004     ['ISX_ISX', 'IX', 'SXI']
# 69.29518894536461     ['ISX_ISX', 'IX', 'IX']
# 69.2951889453646     ['ISX_ISX', 'IX', 'IZ']
# 90.00000000000004     ['ISX_ISX', 'IX', 'ISX']
# 69.2951889453646     ['ISX_ISX', 'IX', 'XX']
# 69.2951889453646     ['ISX_ISX', 'IX', 'ZZ']
# 69.29518894536463     ['ISX_ISX', 'IX', 'ISX_ISX']
# 69.29518894536461     ['ISX_ISX', 'IZ', 'II']
# 69.2951889453646     ['ISX_ISX', 'IZ', 'XI']
# 69.29518894536461     ['ISX_ISX', 'IZ', 'ZI']
# 45.00000000000008     ['ISX_ISX', 'IZ', 'SXI']
# 110.70481105463541     ['ISX_ISX', 'IZ', 'IX']
# 69.29518894536461     ['ISX_ISX', 'IZ', 'IZ']
# 90.00000000000001     ['ISX_ISX', 'IZ', 'ISX']
# 110.7048110546354     ['ISX_ISX', 'IZ', 'XX']
# 69.29518894536461     ['ISX_ISX', 'IZ', 'ZZ']
# 69.29518894536461     ['ISX_ISX', 'IZ', 'ISX_ISX']
# 45.00000000000008     ['ISX_ISX', 'ISX', 'II']
# 90.00000000000004     ['ISX_ISX', 'ISX', 'XI']
# 45.00000000000008     ['ISX_ISX', 'ISX', 'ZI']
# 69.29518894536463     ['ISX_ISX', 'ISX', 'SXI']
# 90.00000000000003     ['ISX_ISX', 'ISX', 'IX']
# 45.00000000000008     ['ISX_ISX', 'ISX', 'IZ']
# 69.29518894536463     ['ISX_ISX', 'ISX', 'ISX']
# 45.00000000000007     ['ISX_ISX', 'ISX', 'XX']
# 45.00000000000008     ['ISX_ISX', 'ISX', 'ZZ']
# 90.00000000000006     ['ISX_ISX', 'ISX', 'ISX_ISX']
# 69.29518894536461     ['ISX_ISX', 'XX', 'II']
# 69.2951889453646     ['ISX_ISX', 'XX', 'XI']
# 69.29518894536461     ['ISX_ISX', 'XX', 'ZI']
# 45.00000000000007     ['ISX_ISX', 'XX', 'SXI']
# 69.2951889453646     ['ISX_ISX', 'XX', 'IX']
# 69.29518894536461     ['ISX_ISX', 'XX', 'IZ']
# 45.00000000000008     ['ISX_ISX', 'XX', 'ISX']
# 69.29518894536461     ['ISX_ISX', 'XX', 'XX']
# 69.29518894536461     ['ISX_ISX', 'XX', 'ZZ']
# 69.29518894536463     ['ISX_ISX', 'XX', 'ISX_ISX']
# 69.29518894536461     ['ISX_ISX', 'ZZ', 'II']
# 110.70481105463541     ['ISX_ISX', 'ZZ', 'XI']
# 69.29518894536461     ['ISX_ISX', 'ZZ', 'ZI']
# 90.00000000000001     ['ISX_ISX', 'ZZ', 'SXI']
# 110.70481105463541     ['ISX_ISX', 'ZZ', 'IX']
# 69.29518894536461     ['ISX_ISX', 'ZZ', 'IZ']
# 90.00000000000001     ['ISX_ISX', 'ZZ', 'ISX']
# 69.29518894536461     ['ISX_ISX', 'ZZ', 'XX']
# 69.29518894536461     ['ISX_ISX', 'ZZ', 'ZZ']
# 110.7048110546354     ['ISX_ISX', 'ZZ', 'ISX_ISX']
# 69.29518894536463     ['ISX_ISX', 'ISX_ISX', 'II']
# 69.29518894536463     ['ISX_ISX', 'ISX_ISX', 'XI']
# 69.29518894536463     ['ISX_ISX', 'ISX_ISX', 'ZI']
# 90.00000000000006     ['ISX_ISX', 'ISX_ISX', 'SXI']
# 69.29518894536463     ['ISX_ISX', 'ISX_ISX', 'IX']
# 69.29518894536463     ['ISX_ISX', 'ISX_ISX', 'IZ']
# 90.00000000000006     ['ISX_ISX', 'ISX_ISX', 'ISX']
# 69.29518894536461     ['ISX_ISX', 'ISX_ISX', 'XX']
# 69.29518894536463     ['ISX_ISX', 'ISX_ISX', 'ZZ']
# 69.29518894536467     ['ISX_ISX', 'ISX_ISX', 'ISX_ISX']

# %%
# para el ghz

# theta(000,GHZ) = 0.7853
# theta(000, W) = 1.57079
# theta(GHZ,W) = 1.57079

GHZ = QuantumCircuit(3)
GHZ.h(0)
GHZ.cx(0,1)
GHZ.cx(1,2)

ghz = Statevector(GHZ)

initial_state = Statevector.from_label("000")

w = Statevector([0,1,1,0,1,0,0,0]/np.linalg.norm(np.array([0,1,1,0,1,0,0,0])))

dis_ghz = d_fs(ghz,initial_state)
dis_w   = d_fs(ghz,w)
print(f"la distancia en drados para el ghz es: {np.degrees(dis_ghz)},  para el estado w: {np.degrees(dis_w)}")

print(f"distancia entre los dos estados gaz y w :  {np.degrees(d_fs(w,ghz))}")
# Out:
# la distancia en drados para el ghz es: 45.00000000000001,  para el estado w: 90.0
# distancia entre los dos estados gaz y w :  90.0
